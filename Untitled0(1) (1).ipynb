# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xvf  /content/drive/MyDrive/crystal_ball_data.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# test_violations/Article10/001-75591.txt
# test_violations/Article13/001-94449.txt
# test_violations/Article3/001-115007.txt
# test_violations/Article5/001-140912.txt
# test_violations/Article6/001-58189.txt
# train/Article3/both/001-163101.txt
# test_violations/Article6/001-59762.txt
# train/Article3/violation/001-98660.txt
# test_violations/Article5/001-175493.txt
# test_violations/Article6/001-92522.txt
# test20/Article6/non-violation/001-122261.txt
# test_violations/Article10/001-154839.txt
# train/Article5/non-violation/001-105336.txt
# test_violations/Article13/001-78223.txt
# test_violations/Article5/001-75437.txt
# test_violations/Article13/001-118599.txt
# test_violations/Article5/001-100281.txt
# test_violations/Article6/001-71507.txt
# train/Article5/both/001-111428.txt
# train/Article6/non-violation/001-59887.txt
# test_violations/Article5/001-98882.txt
# test_violations/Article2/001-86605.txt
# train/Article3/non-violation/001-106771.txt
# train/Article8/violation/001-103251.txt
# train/Article14/violation/001-92945.txt
# test_violations/Article6/001-78944.txt
# train/Article8/violation/001-112021.txt
# test_violations/Article9/001-105129.txt
# test_violations/Article6/001-79507.txt
# test_violations/Article5/001-153472.txt
# test_violations/Article6/001-93248.txt
# test_violations/Article6/001-78439.txt
# test_violations/Article6/001-87209.txt
# train/Article8/violation/001-145017.txt
# train/Article5/both/001-98885.txt
# train/Article5/violation/001-144674.txt
# test_violations/Article8/001-153134.txt
# test_violations/Article10/001-80865.txt
# train/Article14/both/001-69630.txt
# test20/Article3/violation/001-150771.txt
# train/Article10/non-violation/001-57879.txt
# test20/Article18/violation/
# train/Article10/non-violation/001-85085.txt
# train/Article2/both/001-173768.txt
# test_violations/Article6/001-72706.txt
# test_violations/Article2/001-118643.txt
# train/Article6/violation/001-81195.txt
# test_violations/Article6/001-80408.txt
# train/Article6/violation/001-80095.txt
# train/Article3/violation/001-91990.txt
# test_violations/Article3/001-116369.txt
# test_violations/Article6/001-92784.txt
# test_violations/Article6/001-72800.txt
# train/Article5/both/001-148276.txt
# train/Article3/non-violation/001-116740.txt
# test_violations/Article13/001-81423.txt
# test_violations/Article6/001-88502.txt
# test_violations/Article6/001-61451.txt
# test_violations/Article6/001-99174.txt
# test_violations/Article6/001-89508.txt
# train/Article10/non-violation/001-174996.txt
# test_violations/Article8/001-90751.txt
# test_violations/Article10/001-97224.txt
# test_violations/Article6/001-85677.txt
# train/Article5/both/001-57606.txt
# test_violations/Article13/001-112586.txt
# test_violations/Article6/001-110709.txt
# test_violations/Article6/001-76085.txt
# train/Article10/violation/001-96011.txt
# test_violations/Article8/001-161061.txt
# test_violations/Article13/001-158484.txt
# test_violations/Article2/001-103387.txt
# train/Article13/violation/001-152987.txt
# test_violations/Article8/001-119703.txt
# test_violations/Article6/001-81639.txt
# test_violations/Article5/001-93239.txt
# test_violations/Article6/001-78221.txt
# test_violations/Article5/001-163099.txt
# test_violations/Article5/001-104149.txt
# test_violations/Article6/001-147015.txt
# test_violations/Article6/001-72931.txt
# test_violations/Article6/001-80633.txt
# test_violations/Article5/001-59062.txt
# test_violations/Article5/001-101891.txt
# test_violations/Article6/001-73115.txt
# train/Article8/violation/001-146379.txt
# test_violations/Article5/001-105217.txt
# test_violations/Article6/001-114088.txt
# train/Article14/non-violation/001-91431.txt
# test_violations/Article8/001-103216.txt
# test_violations/Article13/001-82211.txt
# train/Article8/violation/001-100543.txt
# test_violations/Article3/001-101586.txt
# test_violations/Article13/001-97256.txt
# test_violations/Article6/001-86086.txt
# test_violations/Article3/001-88895.txt
# train/Article6/non-violation/001-57425.txt
# train/Article10/violation/001-58276.txt
# test20/Article6/violation/001-86853.txt
# test_violations/Article6/001-90129.txt
# test_violations/Article6/001-91608.txt
# test_violations/Article9/001-127809.txt
# train/Article5/both/001-108607.txt
# test_violations/Article6/001-57842.txt
# train/Article3/non-violation/001-142655.txt
# test_violations/Article13/001-120070.txt
# train/Article13/violation/001-84809.txt
# test_violations/Article6/001-73246.txt
# test_violations/Article10/001-82030.txt
# test_violations/Article13/001-75235.txt
# test20/Article8/non-violation/001-90480.txt
# test20/Article5/non-violation/001-77657.txt
# test_violations/Article13/001-101223.txt
# train/Article3/non-violation/001-61681.txt
# test_violations/Article5/001-57702.txt
# test_violations/Article6/001-96466.txt
# test_violations/Article6/001-60911.txt
# train/Article6/violation/001-109091.txt
# train/Article4/violation/001-75934.txt
# test_violations/Article8/001-148271.txt
# test_violations/Article6/001-95871.txt
# test_violations/Article3/001-127220.txt
# test_violations/Article13/001-104939.txt
# test20/Article6/non-violation/001-145224.txt
# test_violations/Article6/001-59668.txt
# test_violations/Article8/001-57603.txt
# test_violations/Article2/001-91319.txt
# test_violations/Article2/001-154148.txt
# test_violations/Article6/001-90765.txt
# train/Article6/violation/001-79442.txt
# train/Article13/non-violation/001-57804.txt
# test_violations/Article2/001-146540.txt
# test_violations/Article3/001-99932.txt
# test_violations/Article13/001-100791.txt
# test_violations/Article6/001-58157.txt
# test_violations/Article6/001-67432.txt
# test_violations/Article11/001-169473.txt
# test_violations/Article3/001-97385.txt
# test_violations/Article6/001-90322.txt
# test_violations/Article2/001-89922.txt
# train/Article14/violation/001-158033.txt
# test_violations/Article13/001-61963.txt
# test_violations/Article10/001-60172.txt
# train/Article13/non-violation/001-171804.txt
# test_violations/Article8/001-103161.txt
# test_violations/Article8/001-100508.txt
# test_violations/Article5/001-97557.txt
# test_violations/Article3/001-152889.txt
# train/Article2/both/001-147036.txt
# test20/Article8/non-violation/001-89634.txt
# test_violations/Article6/001-84446.txt
# test_violations/Article2/001-92107.txt
# test_violations/Article6/001-86109.txt
# train/Article8/non-violation/001-145068.txt
# test_violations/Article2/001-115019.txt
# test_violations/Article6/001-59861.txt
# test_violations/Article3/001-98552.txt
# test_violations/Article6/001-75265.txt
# train/Article5/violation/001-90135.txt
# test_violations/Article6/001-70538.txt
# test_violations/Article13/001-58818.txt
# train/Article11/violation/001-108615.txt
# test_violations/Article14/001-57541.txt
# test_violations/Article6/001-68220.txt
# test_violations/Article9/001-82179.txt
# train/Article3/both/001-111837.txt
# train/Article8/violation/001-87156.txt
# train/Article6/non-violation/001-59986.txt
# test_violations/Article6/001-61357.txt
# train/Article6/violation/001-80063.txt
# test_violations/Article2/001-113767.txt
# test_violations/Article6/001-61830.txt
# test_violations/Article5/001-58242.txt
# train/Article8/non-violation/001-83583.txt
# train/Article8/violation/001-91704.txt
# test20/Article8/non-violation/001-58021.txt
# test_violations/Article3/001-116973.txt
# test_violations/Article3/001-95203.txt
# test_violations/Article3/001-160428.txt
# test_violations/Article3/001-93671.txt
# train/Article3/violation/001-72700.txt
# test20/Article6/violation/001-97362.txt
# test_violations/Article6/001-94415.txt
# train/Article6/violation/001-83873.txt
# test_violations/Article13/001-85087.txt
# test_violations/Article13/001-159047.txt
# test_violations/Article5/001-67274.txt
# test_violations/Article2/001-145571.txt
# test_violations/Article5/001-59884.txt
# test_violations/Article3/001-108580.txt
# test_violations/Article5/001-86605.txt
# train/Article5/non-violation/001-113741.txt
# test_violations/Article6/001-70763.txt
# test_violations/Article5/001-104939.txt
# test_violations/Article13/001-100309.txt
# test20/Article2/non-violation/001-80046.txt
# test_violations/Article5/001-75892.txt
# test_violations/Article5/001-157533.txt
# train/Article6/violation/001-70528.txt
# test_violations/Article6/001-79769.txt
# test_violations/Article3/001-115873.txt
# test_violations/Article9/001-93310.txt
# train/Article5/violation/001-97292.txt
# test_violations/Article6/001-61550.txt
# train/Article6/non-violation/001-77246.txt
# test_violations/Article2/001-85767.txt
# test_violations/Article6/001-94578.txt
# train/Article13/violation/001-61796.txt
# train/Article3/non-violation/001-103526.txt
# train/Article6/both/001-69670.txt
# test_violations/Article3/001-60505.txt
# test_violations/Article3/001-99707.txt
# test_violations/Article5/001-61442.txt
# test_violations/Article6/001-100559.txt
# test_violations/Article8/001-100042.txt
# test_violations/Article6/001-94135.txt
# test_violations/Article6/001-66929.txt
# test_violations/Article6/001-94640.txt
# train/Article6/non-violation/001-105355.txt
# test_violations/Article5/001-86961.txt
# train/Article8/violation/001-61228.txt
# test_violations/Article5/001-112586.txt
# test_violations/Article5/001-59099.txt
# train/Article3/violation/001-112534.txt
# test_violations/Article5/001-82494.txt
# test_violations/Article6/001-98508.txt
# test_violations/Article13/001-68601.txt
# test_violations/Article13/001-81242.txt
# test_violations/Article6/001-57810.txt
# test_violations/Article13/001-75614.txt
# test_violations/Article13/001-100029.txt
# train/Article3/violation/001-119971.txt
# train/Article6/non-violation/001-85079.txt
# test_violations/Article14/001-61940.txt
# train/Article5/both/001-112540.txt
# train/Article8/both/001-57781.txt
# train/Article14/non-violation/001-57906.txt
# train/Article13/violation/001-114777.txt
# train/Article3/non-violation/001-167538.txt
# train/Article6/both/001-127399.txt
# train/Article8/non-violation/001-105624.txt
# test_violations/Article6/001-95366.txt
# test_violations/Article6/001-102858.txt
# test_violations/Article10/001-59588.txt
# test_violations/Article13/001-88585.txt
# test_violations/Article3/001-140240.txt
# train/Article7/violation/001-107556.txt
# train/Article18/violation/001-61767.txt
# train/Article3/non-violation/001-148076.txt
# train/Article13/non-violation/001-70445.txt
# train/Article3/non-violation/001-93166.txt
# test_violations/Article6/001-88321.txt
# test_violations/Article6/001-96023.txt
# train/Article8/violation/001-99176.txt
# test_violations/Article9/001-144681.txt
# test_violations/Article6/001-57468.txt
# test_violations/Article8/001-61442.txt
# test_violations/Article6/001-156520.txt
# test_violations/Article13/001-83447.txt
# test_violations/Article11/001-88748.txt
# test_violations/Article6/001-57562.txt
# test_violations/Article6/001-81047.txt
# test_violations/Article13/001-83541.txt
# test_violations/Article9/001-91608.txt
# test_violations/Article3/001-59455.txt
# test_violations/Article3/001-82377.txt
# test_violations/Article13/001-58072.txt
# test_violations/Article5/001-58901.txt
# test_violations/Article13/001-73260.txt
# test_violations/Article5/001-72642.txt
# train/Article6/violation/001-96867.txt
# test_violations/Article5/001-107335.txt
# test_violations/Article6/001-88484.txt
# test_violations/Article10/001-141763.txt
# train/Article5/violation/001-101682.txt
# test_violations/Article6/001-89552.txt
# train/Article3/non-violation/001-173265.txt
# test_violations/Article13/001-98175.txt
# test_violations/Article5/001-58559.txt
# test_violations/Article13/001-113808.txt
# test_violations/Article5/001-95451.txt
# test_violations/Article5/001-86681.txt
# test_violations/Article6/001-97633.txt
# train/Article14/violation/001-80464.txt
# test20/Article3/non-violation/001-164672.txt
# test_violations/Article6/001-91932.txt
# test_violations/Article9/001-79583.txt
# test_violations/Article6/001-75644.txt
# test_violations/Article6/001-80583.txt
# test_violations/Article6/001-76712.txt
# test_violations/Article6/001-81240.txt
# train/Article3/both/001-169475.txt
# train/Article8/violation/001-87567.txt
# train/Article5/both/001-107452.txt
# train/Article6/both/001-113273.txt
# train/Article6/violation/001-90218.txt
# test_violations/Article5/001-91319.txt
# test_violations/Article6/001-60668.txt
# train/Article8/both/001-120070.txt
# test20/Article6/violation/001-59712.txt
# train/Article3/non-violation/001-81114.txt
# test_violations/Article14/001-107110.txt
# test_violations/Article5/001-169521.txt
# test_violations/Article6/001-61325.txt
# test_violations/Article2/001-68379.txt
# train/Article10/non-violation/001-140395.txt
# test_violations/Article8/001-57865.txt
# train/Article5/both/001-57781.txt
# train/Article3/both/001-145791.txt
# test_violations/Article10/001-94840.txt
# test_violations/Article6/001-158950.txt
# test_violations/Article6/001-59992.txt
# test_violations/Article13/001-77796.txt
# train/Article14/violation/001-113876.txt
# test20/Article6/non-violation/001-162020.txt
# test_violations/Article10/001-104685.txt
# test_violations/Article6/001-105123.txt
# train/Article6/non-violation/001-60855.txt
# test_violations/Article2/001-91138.txt
# test_violations/Article6/001-59076.txt
# test20/Article14/violation/001-86341.txt
# test_violations/Article6/001-77500.txt
# test_violations/Article6/001-90173.txt
# test_violations/Article6/001-85202.txt
# train/Article10/non-violation/001-85152.txt
# train/Article2/both/001-70160.txt
# test20/Article6/non-violation/001-57950.txt
# test_violations/Article5/001-92107.txt
# test_violations/Article6/001-61961.txt
# train/Article2/both/001-104636.txt
# test_violations/Article5/001-116330.txt
# test_violations/Article2/001-92369.txt
# train/Article8/non-violation/001-108431.txt
# test_violations/Article2/001-155198.txt
# test_violations/Article2/001-112536.txt
# test_violations/Article6/001-94957.txt
# test_violations/Article6/001-120063.txt
# test_violations/Article6/001-93951.txt
# test_violations/Article6/001-79326.txt
# test_violations/Article6/001-159770.txt
# test_violations/Article6/001-92883.txt
# test_violations/Article6/001-93446.txt
# train/Article6/violation/001-78528.txt
# test_violations/Article13/001-95056.txt
# test_violations/Article9/001-172073.txt
# test_violations/Article10/001-69091.txt
# test_violations/Article13/001-86286.txt
# test_violations/Article13/001-87354.txt
# train/Article8/non-violation/001-61188.txt
# test_violations/Article6/001-95203.txt
# test_violations/Article6/001-72936.txt
# test_violations/Article6/001-76152.txt
# test_violations/Article6/001-57716.txt
# test_violations/Article5/001-76455.txt
# test_violations/Article9/001-92752.txt
# test_violations/Article5/001-93306.txt
# test_violations/Article3/001-97863.txt
# test_violations/Article5/001-164677.txt
# train/Article6/violation/001-60883.txt
# test_violations/Article6/001-116734.txt
# test_violations/Article6/001-72114.txt
# test_violations/Article3/001-141625.txt
# test_violations/Article13/001-87896.txt
# train/Article3/both/001-158243.txt
# train/Article8/violation/001-161760.txt
# train/Article11/non-violation/001-57993.txt
# test_violations/Article6/001-75107.txt
# test_violations/Article5/001-85487.txt
# test_violations/Article9/001-79769.txt
# test_violations/Article5/001-91395.txt
# test_violations/Article6/001-88700.txt
# test_violations/Article9/001-89607.txt
# train/Article6/both/001-159768.txt
# train/Article6/non-violation/001-158491.txt
# test_violations/Article6/001-93260.txt
# test_violations/Article6/001-59604.txt
# train/Article8/non-violation/001-57510.txt
# test_violations/Article13/001-171527.txt
# test_violations/Article6/001-57941.txt
# test_violations/Article6/001-57436.txt
# test_violations/Article6/001-73196.txt
# test_violations/Article5/001-58807.txt
# test_violations/Article6/001-142518.txt
# train/Article6/non-violation/001-101958.txt
# test_violations/Article6/001-57530.txt
# test_violations/Article10/001-170354.txt
# test_violations/Article6/001-80420.txt
# train/Article13/violation/001-67614.txt
# test_violations/Article13/001-72160.txt
# train/Article6/violation/001-71036.txt
# test_violations/Article13/001-90111.txt
# train/Article6/non-violation/001-80956.txt
# test_violations/Article9/001-57810.txt
# train/Article11/violation/001-59689.txt
# test_violations/Article6/001-100883.txt
# test_violations/Article6/001-171777.txt
# test_violations/Article8/001-59161.txt
# test_violations/Article9/001-101645.txt
# test20/Article14/non-violation/001-58162.txt
# test_violations/Article9/001-95777.txt
# train/Article3/violation/001-120971.txt
# test20/Article6/violation/001-93685.txt
# test_violations/Article13/001-83578.txt
# test20/Article12/violation/
# train/Article8/non-violation/001-57641.txt
# train/Article2/non-violation/001-159044.txt
# test_violations/Article6/001-58798.txt
# test_violations/Article6/001-57661.txt
# test_violations/Article6/001-58256.txt
# test_violations/Article6/001-75612.txt
# test_violations/Article10/001-58270.txt
# train/Article3/non-violation/001-144137.txt
# test_violations/Article6/001-81651.txt
# test20/Article11/violation/001-167094.txt
# train/Article6/violation/001-58526.txt
# test20/Article2/violation/001-100659.txt
# test_violations/Article6/001-73033.txt
# test_violations/Article5/001-93382.txt
# train/Article6/violation/001-145223.txt
# test_violations/Article13/001-76122.txt
# test_violations/Article6/001-151008.txt
# test_violations/Article2/001-172329.txt
# test20/Article8/non-violation/001-128204.txt
# train/Article8/violation/001-75591.txt
# test_violations/Article5/001-100029.txt
# test20/Article10/non-violation/001-102837.txt
# test_violations/Article5/001-89922.txt
# train/Article3/violation/001-128055.txt
# test_violations/Article13/001-127404.txt
# test_violations/Article6/001-110379.txt
# test_violations/Article6/001-97353.txt
# test_violations/Article6/001-95185.txt
# test_violations/Article6/001-83445.txt
# test_violations/Article6/001-77817.txt
# test_violations/Article13/001-86945.txt
# train/Article6/non-violation/001-61829.txt
# test_violations/Article9/001-173800.txt
# test_violations/Article6/001-90963.txt
# test20/Article6/non-violation/001-109219.txt
# test_violations/Article13/001-79427.txt
# train/Article3/both/001-59219.txt
# train/Article6/non-violation/001-148676.txt
# train/Article3/both/001-126912.txt
# train/Article3/violation/001-102818.txt
# test_violations/Article6/001-92215.txt
# test_violations/Article6/001-66562.txt
# test_violations/Article8/001-89823.txt
# test_violations/Article5/001-78573.txt
# test_violations/Article5/001-91138.txt
# test_violations/Article13/001-61277.txt
# train/Article2/both/001-108231.txt
# test_violations/Article8/001-58559.txt
# train/Article13/violation/001-84821.txt
# test_violations/Article9/001-121615.txt
# train/Article3/non-violation/001-110918.txt
# test_violations/Article5/001-171527.txt
# test_violations/Article5/001-119043.txt
# train/Article7/both/
# test_violations/Article5/001-103938.txt
# test_violations/Article5/001-140768.txt
# train/Article2/both/001-59219.txt
# test_violations/Article3/001-94202.txt
# train/Article8/non-violation/001-60499.txt
# train/Article5/violation/001-144367.txt
# train/Article6/non-violation/001-61549.txt
# train/Article5/violation/001-92028.txt
# test_violations/Article5/001-81773.txt
# test_violations/Article6/001-60992.txt
# train/Article10/violation/001-57523.txt
# train/Article6/non-violation/001-61138.txt
# test_violations/Article8/001-168377.txt
# test_violations/Article6/001-90272.txt
# train/Article6/both/001-99871.txt
# test_violations/Article6/001-76120.txt
# test_violations/Article5/001-100385.txt
# test_violations/Article6/001-81091.txt
# train/Article3/violation/001-93851.txt
# test_violations/Article6/001-60487.txt
# test_violations/Article3/001-113416.txt
# test_violations/Article6/001-61555.txt
# train/Article6/violation/001-142515.txt
# train/Article3/non-violation/001-114770.txt
# test20/Article6/violation/001-98598.txt
# test_violations/Article3/001-154153.txt
# test_violations/Article6/001-61144.txt
# test_violations/Article5/001-61415.txt
# train/Article8/non-violation/001-110942.txt
# train/Article3/non-violation/001-140012.txt
# test_violations/Article6/001-107016.txt
# test_violations/Article6/001-107521.txt
# test_violations/Article6/001-163912.txt
# train/Article14/non-violation/001-60645.txt
# test_violations/Article8/001-145350.txt
# train/Article6/violation/001-76964.txt
# test_violations/Article3/001-158806.txt
# test_violations/Article13/001-79751.txt
# test20/Article6/violation/001-166488.txt
# train/Article6/both/001-57903.txt
# test_violations/Article13/001-175154.txt
# test_violations/Article6/001-83390.txt
# test_violations/Article9/001-86339.txt
# test_violations/Article6/001-57815.txt
# train/Article14/violation/001-99384.txt
# test_violations/Article8/001-111938.txt
# test_violations/Article6/001-73219.txt
# test_violations/Article3/001-58897.txt
# test_violations/Article3/001-172104.txt
# train/Article5/violation/001-169475.txt
# test_violations/Article3/001-113921.txt
# train/Article5/violation/001-113296.txt
# test_violations/Article3/001-99905.txt
# train/Article5/both/001-156275.txt
# test20/Article2/non-violation/001-60329.txt
# test_violations/Article2/001-92693.txt
# test_violations/Article5/001-157763.txt
# test_violations/Article3/001-58734.txt
# train/Article8/violation/001-68732.txt
# test_violations/Article3/001-123362.txt
# test_violations/Article13/001-61805.txt
# train/Article6/non-violation/001-72749.txt
# test_violations/Article6/001-97507.txt
# train/Article5/violation/001-145791.txt
# test_violations/Article5/001-101173.txt
# test_violations/Article10/001-58587.txt
# train/Article8/violation/001-58072.txt
# test_violations/Article5/001-126972.txt
# test_violations/Article6/001-57978.txt
# test_violations/Article13/001-82889.txt
# test20/Article10/non-violation/001-175121.txt
# train/Article2/both/001-153801.txt
# train/Article14/violation/001-57416.txt
# test_violations/Article5/001-94861.txt
# test_violations/Article6/001-110441.txt
# test_violations/Article6/001-90706.txt
# test_violations/Article9/001-171501.txt
# test_violations/Article3/001-174403.txt
# test_violations/Article6/001-80457.txt
# test_violations/Article3/001-147271.txt
# test_violations/Article6/001-100440.txt
# test_violations/Article6/001-91115.txt
# test_violations/Article6/001-150319.txt
# test_violations/Article6/001-70681.txt
# test20/Article12/non-violation/
# test_violations/Article13/001-73265.txt
# train/Article6/non-violation/001-100036.txt
# train/Article2/both/001-77657.txt
# test_violations/Article6/001-81688.txt
# train/Article3/violation/001-145317.txt
# train/Article14/non-violation/001-69022.txt
# test_violations/Article2/001-88673.txt
# test_violations/Article6/001-166937.txt
# test_violations/Article6/001-98327.txt
# test_violations/Article6/001-75238.txt
# train/Article5/violation/001-117894.txt
# train/Article8/non-violation/001-110382.txt
# test_violations/Article6/001-141200.txt
# test_violations/Article10/001-77831.txt
# test20/Article14/non-violation/001-60168.txt
# test_violations/Article6/001-72980.txt
# train/Article3/non-violation/001-159212.txt
# train/Article6/violation/001-81958.txt
# test_violations/Article10/001-68650.txt
# test_violations/Article13/001-140013.txt
# train/Article6/violation/001-148292.txt
# test_violations/Article6/001-163352.txt
# train/Article6/both/001-59511.txt
# test_violations/Article6/001-90931.txt
# train/Article5/violation/001-72662.txt
# test_violations/Article10/001-60687.txt
# test_violations/Article8/001-77785.txt
# test_violations/Article13/001-101552.txt
# test_violations/Article8/001-167557.txt
# test_violations/Article13/001-84334.txt
# test_violations/Article6/001-73164.txt
# test_violations/Article5/001-78293.txt
# test_violations/Article9/001-142504.txt
# test_violations/Article3/001-99214.txt
# test_violations/Article3/001-91788.txt
# test_violations/Article6/001-60735.txt
# test_violations/Article6/001-96795.txt
# test_violations/Article6/001-89277.txt
# train/Article5/both/001-58854.txt
# train/Article6/violation/001-73023.txt
# train/Article6/non-violation/001-57885.txt
# test_violations/Article5/001-57620.txt
# train/Article5/both/001-147622.txt
# train/Article8/violation/001-57438.txt
# test_violations/Article6/001-59997.txt
# test_violations/Article2/001-146775.txt
# test_violations/Article6/001-76942.txt
# test_violations/Article6/001-82887.txt
# test_violations/Article9/001-61704.txt
# test_violations/Article6/001-83955.txt
# train/Article6/non-violation/001-61928.txt
# test_violations/Article6/001-78605.txt
# test20/Article3/violation/001-108397.txt
# train/Article6/violation/001-82746.txt
# test20/Article14/violation/001-138892.txt
# test_violations/Article8/001-161002.txt
# train/Article3/violation/001-98452.txt
# test_violations/Article13/001-164464.txt
# train/Article14/non-violation/001-58139.txt
# test20/Article10/non-violation/001-109046.txt
# test20/Article8/violation/001-169661.txt
# test_violations/Article3/001-115846.txt
# test20/Article6/violation/001-58020.txt
# test_violations/Article6/001-69966.txt
# test_violations/Article6/001-77668.txt
# test_violations/Article6/001-103690.txt
# test_violations/Article3/001-94301.txt
# train/Article6/violation/001-157528.txt
# test_violations/Article2/001-158501.txt
# test_violations/Article9/001-98552.txt
# test_violations/Article2/001-91841.txt
# test_violations/Article3/001-100964.txt
# test_violations/Article2/001-90362.txt
# test_violations/Article6/001-70867.txt
# test_violations/Article2/001-99430.txt
# test_violations/Article10/001-138568.txt
# train/Article3/non-violation/001-98688.txt
# test_violations/Article3/001-109116.txt
# test_violations/Article5/001-61957.txt
# test_violations/Article14/001-100197.txt
# test_violations/Article6/001-61275.txt
# test20/Article6/violation/001-81073.txt
# test_violations/Article2/001-89592.txt
# test_violations/Article3/001-114087.txt
# test_violations/Article6/001-71113.txt
# train/Article5/violation/001-84588.txt
# train/Article14/violation/001-161530.txt
# train/Article8/violation/001-72098.txt
# train/Article6/non-violation/001-84046.txt
# test20/Article5/non-violation/001-57573.txt
# test_violations/Article6/001-112086.txt
# test_violations/Article6/001-94744.txt
# test_violations/Article8/001-146044.txt
# test_violations/Article2/001-106167.txt
# train/Article8/non-violation/001-57515.txt
# test_violations/Article13/001-78371.txt
# test_violations/Article6/001-81936.txt
# train/Article6/non-violation/001-60394.txt
# test_violations/Article8/001-61415.txt
# train/Article6/non-violation/001-153769.txt
# test_violations/Article6/001-86220.txt
# test_violations/Article6/001-57535.txt
# test_violations/Article3/001-105434.txt
# test_violations/Article10/001-98752.txt
# test_violations/Article3/001-152644.txt
# test_violations/Article2/001-93798.txt
# test_violations/Article3/001-157968.txt
# test_violations/Article8/001-58098.txt
# test_violations/Article2/001-87348.txt
# test_violations/Article3/001-87045.txt
# test_violations/Article6/001-78587.txt
# test20/Article6/violation/001-70532.txt
# test20/Article13/violation/001-97151.txt
# test_violations/Article13/001-107159.txt
# test_violations/Article2/001-96118.txt
# test_violations/Article13/001-89851.txt
# test_violations/Article3/001-167806.txt
# test_violations/Article3/001-156078.txt
# test_violations/Article6/001-100477.txt
# test_violations/Article6/001-139773.txt
# test_violations/Article6/001-103208.txt
# test_violations/Article6/001-82219.txt
# test_violations/Article6/001-67915.txt
# test_violations/Article6/001-82724.txt
# test_violations/Article6/001-57666.txt
# test_violations/Article6/001-147443.txt
# test_violations/Article6/001-90426.txt
# test_violations/Article13/001-158090.txt
# test_violations/Article6/001-72475.txt
# test_violations/Article3/001-145817.txt
# test20/Article5/non-violation/001-94837.txt
# train/Article7/non-violation/001-58139.txt
# test20/Article14/non-violation/001-67984.txt
# test_violations/Article5/001-80416.txt
# test_violations/Article6/001-90146.txt
# test_violations/Article6/001-142305.txt
# test_violations/Article11/001-170857.txt
# test_violations/Article6/001-105507.txt
# train/Article11/non-violation/001-140910.txt
# train/Article8/violation/
# test_violations/Article3/001-91756.txt
# test20/Article3/violation/001-147269.txt
# test_violations/Article13/001-99852.txt
# test_violations/Article8/001-78410.txt
# test_violations/Article8/001-170390.txt
# test20/Article8/non-violation/001-102894.txt
# train/Article3/non-violation/001-173463.txt
# train/Article3/both/001-89009.txt
# test_violations/Article3/001-105402.txt
# test20/Article6/non-violation/001-116836.txt
# test_violations/Article6/001-57797.txt
# test_violations/Article6/001-59522.txt
# test_violations/Article5/001-79267.txt
# test_violations/Article8/001-160313.txt
# test_violations/Article6/001-148263.txt
# test_violations/Article11/001-72521.txt
# test_violations/Article2/001-90610.txt
# test_violations/Article13/001-155662.txt
# test_violations/Article8/001-109191.txt
# train/Article3/violation/001-101817.txt
# test_violations/Article9/001-81688.txt
# train/Article3/violation/001-107201.txt
# test_violations/Article6/001-73263.txt
# test_violations/Article6/001-150643.txt
# test_violations/Article5/001-88673.txt
# test_violations/Article9/001-83824.txt
# train/Article3/both/001-175680.txt
# test_violations/Article6/001-97489.txt
# test_violations/Article5/001-75702.txt
# test_violations/Article5/001-101327.txt
# test_violations/Article6/001-75468.txt
# test_violations/Article5/001-97411.txt
# test_violations/Article6/001-89881.txt
# test_violations/Article6/001-103153.txt
# test_violations/Article13/001-60781.txt
# test20/Article10/non-violation/001-158709.txt
# test_violations/Article6/001-60423.txt
# train/Article14/non-violation/001-109809.txt
# test_violations/Article13/001-78968.txt
# train/Article8/both/001-70138.txt
# test_violations/Article5/001-99430.txt
# test_violations/Article6/001-91756.txt
# test_violations/Article6/001-66792.txt
# train/Article10/violation/001-142424.txt
# train/Article5/both/001-60954.txt
# test_violations/Article9/001-146393.txt
# train/Article8/both/001-118602.txt
# test_violations/Article9/001-60324.txt
# test20/Article8/violation/001-160692.txt
# test_violations/Article9/001-101152.txt
# test_violations/Article6/001-75562.txt
# train/Article6/both/001-110949.txt
# test_violations/Article6/001-76125.txt
# test_violations/Article6/001-58174.txt
# train/Article6/violation/001-83029.txt
# train/Article6/violation/001-60856.txt
# train/Article5/non-violation/001-164682.txt
# train/Article8/violation/001-89621.txt
# test20/Article3/non-violation/001-145711.txt
# test_violations/Article6/001-61149.txt
# train/Article8/both/001-81618.txt
# test_violations/Article3/001-109527.txt
# train/Article6/non-violation/001-58299.txt
# test_violations/Article8/001-175140.txt
# test_violations/Article6/001-76699.txt
# train/Article7/violation/001-61628.txt
# test_violations/Article6/001-97271.txt
# train/Article14/violation/001-92425.txt
# train/Article14/violation/001-76137.txt
# train/Article5/non-violation/001-77659.txt
# test_violations/Article6/001-68586.txt
# test_violations/Article5/001-91972.txt
# test_violations/Article2/001-69202.txt
# test_violations/Article5/001-78167.txt
# test_violations/Article6/001-76070.txt
# test_violations/Article11/001-61638.txt
# train/Article5/violation/001-161542.txt
# test_violations/Article6/001-92165.txt
# test_violations/Article6/001-67580.txt
# test_violations/Article13/001-72987.txt
# test_violations/Article5/001-114080.txt
# test_violations/Article6/001-72629.txt
# test_violations/Article10/001-70096.txt
# test_violations/Article6/001-57914.txt
# test20/Article8/non-violation/001-57792.txt
# test_violations/Article18/001-58162.txt
# test_violations/Article3/001-61062.txt
# test_violations/Article5/001-90362.txt
# test_violations/Article13/001-73139.txt
# test_violations/Article6/001-71623.txt
# test_violations/Article6/001-61374.txt
# test_violations/Article6/001-79655.txt
# train/Article14/violation/001-91993.txt
# test_violations/Article6/001-78555.txt
# test_violations/Article6/001-71212.txt
# test_violations/Article6/001-87830.txt
# test_violations/Article8/001-75454.txt
# test_violations/Article6/001-76892.txt
# test_violations/Article8/001-61546.txt
# test_violations/Article6/001-93775.txt
# test_violations/Article9/001-114520.txt
# train/Article6/violation/001-98361.txt
# train/Article5/non-violation/001-91499.txt
# test_violations/Article13/001-112098.txt
# test20/Article8/violation/001-76114.txt
# test_violations/Article6/001-106240.txt
# test_violations/Article13/001-96453.txt
# train/Article6/violation/001-171088.txt
# test20/Article5/violation/001-105612.txt
# test_violations/Article2/001-109913.txt
# test_violations/Article6/001-91290.txt
# test_violations/Article6/001-72854.txt
# test_violations/Article8/001-61135.txt
# test_violations/Article6/001-58229.txt
# train/Article5/non-violation/001-67192.txt
# test_violations/Article5/001-93798.txt
# test20/Article3/non-violation/001-164202.txt
# test_violations/Article3/001-109883.txt
# test_violations/Article3/001-96357.txt
# test_violations/Article6/001-71343.txt
# train/Article6/non-violation/001-144276.txt
# test_violations/Article6/001-86071.txt
# test_violations/Article6/001-61094.txt
# train/Article8/violation/001-82198.txt
# train/Article10/violation/001-61105.txt
# test_violations/Article6/001-101233.txt
# test_violations/Article3/001-150313.txt
# train/Article8/non-violation/001-83809.txt
# test_violations/Article6/001-86893.txt
# test_violations/Article6/001-79375.txt
# test_violations/Article13/001-113297.txt
# train/Article6/non-violation/001-128050.txt
# test_violations/Article6/001-57765.txt
# test_violations/Article6/001-72985.txt
# test_violations/Article6/001-73169.txt
# test_violations/Article6/001-93084.txt
# test_violations/Article6/001-102239.txt
# train/Article3/violation/001-111389.txt
# test_violations/Article6/001-163357.txt
# train/Article5/non-violation/001-79235.txt
# train/Article5/both/001-169648.txt
# test20/Article6/violation/001-107550.txt
# test_violations/Article9/001-156006.txt
# train/Article8/violation/001-104839.txt
# test_violations/Article13/001-100962.txt
# train/Article8/both/001-106433.txt
# test_violations/Article6/001-81344.txt
# test_violations/Article6/001-75305.txt
# train/Article13/both/001-97636.txt
# test_violations/Article6/001-98968.txt
# train/Article8/non-violation/001-99605.txt
# test_violations/Article6/001-141368.txt
# train/Article8/non-violation/001-79486.txt
# test_violations/Article6/001-88687.txt
# test_violations/Article3/001-126454.txt
# test_violations/Article11/001-92094.txt
# test_violations/Article3/001-158887.txt
# test_violations/Article6/001-59559.txt
# test20/Article18/non-violation/
# test_violations/Article6/001-57990.txt
# test_violations/Article6/001-96451.txt
# test20/Article3/non-violation/001-111553.txt
# test20/Article5/violation/001-112097.txt
# train/Article6/non-violation/001-57541.txt
# test_violations/Article9/001-60703.txt
# test_violations/Article5/001-90610.txt
# test20/Article10/non-violation/001-96484.txt
# test20/Article6/non-violation/001-113288.txt
# test_violations/Article6/001-119677.txt
# test_violations/Article6/001-156064.txt
# train/Article3/violation/001-105164.txt
# train/Article3/violation/001-108400.txt
# test_violations/Article6/001-68423.txt
# test_violations/Article3/001-158033.txt
# test_violations/Article3/001-98376.txt
# test_violations/Article8/001-97218.txt
# train/Article3/violation/001-94419.txt
# test_violations/Article2/001-114099.txt
# test_violations/Article5/001-112098.txt
# train/Article3/violation/001-101505.txt
# test_violations/Article3/001-145225.txt
# test_violations/Article5/001-104490.txt
# train/Article6/non-violation/001-79282.txt
# train/Article13/violation/001-59456.txt
# test_violations/Article8/001-67906.txt
# test20/Article5/non-violation/001-101952.txt
# test_violations/Article13/001-70245.txt
# train/Article3/non-violation/001-166680.txt
# test_violations/Article6/001-67897.txt
# test_violations/Article6/001-91887.txt
# test_violations/Article6/001-61211.txt
# test_violations/Article5/001-138554.txt
# test_violations/Article6/001-84369.txt
# test_violations/Article5/001-98610.txt
# test_violations/Article13/001-85763.txt
# test_violations/Article13/001-105712.txt
# train/Article6/non-violation/001-172963.txt
# train/Article3/both/001-71594.txt
# test_violations/Article6/001-93107.txt
# test_violations/Article13/001-78245.txt
# train/Article3/both/001-150315.txt
# test_violations/Article6/001-90470.txt
# test_violations/Article9/001-93419.txt
# test_violations/Article5/001-169476.txt
# train/Article3/violation/001-107020.txt
# test_violations/Article5/001-80398.txt
# test_violations/Article3/001-108969.txt
# train/Article8/violation/001-103273.txt
# test_violations/Article6/001-71118.txt
# test_violations/Article5/001-146387.txt
# test_violations/Article13/001-73107.txt
# test_violations/Article5/001-81691.txt
# test_violations/Article6/001-114259.txt
# train/Article3/non-violation/001-121570.txt
# test_violations/Article6/001-78966.txt
# train/Article5/non-violation/001-89592.txt
# test_violations/Article8/001-152593.txt
# test_violations/Article5/001-59364.txt
# test_violations/Article6/001-108856.txt
# test_violations/Article6/001-100413.txt
# test_violations/Article2/001-172440.txt
# test_violations/Article3/001-107141.txt
# test_violations/Article6/001-153767.txt
# test_violations/Article6/001-90190.txt
# test_violations/Article6/001-58608.txt
# test_violations/Article5/001-154151.txt
# test_violations/Article3/001-80623.txt
# train/Article3/both/001-92028.txt
# train/Article3/non-violation/001-69216.txt
# train/Article6/non-violation/001-71305.txt
# test20/Article6/violation/001-75264.txt
# train/Article5/non-violation/001-158494.txt
# test_violations/Article9/001-77356.txt
# train/Article6/violation/001-149202.txt
# test_violations/Article6/001-126807.txt
# test_violations/Article9/001-94301.txt
# test_violations/Article13/001-122889.txt
# train/Article14/non-violation/001-59157.txt
# test_violations/Article8/001-106171.txt
# test_violations/Article9/001-69243.txt
# test_violations/Article13/001-58523.txt
# train/Article2/violation/
# train/Article14/violation/001-160692.txt
# test_violations/Article6/001-70243.txt
# train/Article6/violation/001-71613.txt
# test_violations/Article2/001-104851.txt
# train/Article6/non-violation/001-142076.txt
# test_violations/Article13/001-101936.txt
# test_violations/Article13/001-60019.txt
# train/Article5/non-violation/001-108856.txt
# test_violations/Article2/001-105102.txt
# test_violations/Article11/001-73291.txt
# test_violations/Article2/001-76066.txt
# test_violations/Article6/001-165755.txt
# train/Article3/violation/001-60509.txt
# test_violations/Article5/001-85559.txt
# test_violations/Article14/001-109084.txt
# train/Article10/non-violation/001-88063.txt
# test_violations/Article6/001-149205.txt
# test_violations/Article5/001-79109.txt
# test_violations/Article6/001-57733.txt
# train/Article6/violation/001-77034.txt
# test_violations/Article2/001-160420.txt
# test_violations/Article3/001-81000.txt
# train/Article5/non-violation/001-57625.txt
# test_violations/Article5/001-110683.txt
# test_violations/Article6/001-72037.txt
# train/Article14/non-violation/001-58282.txt
# test_violations/Article3/001-117684.txt
# test_violations/Article13/001-154025.txt
# test_violations/Article8/001-172563.txt
# test_violations/Article3/001-82548.txt
# test_violations/Article3/001-98344.txt
# test_violations/Article3/001-109066.txt
# test_violations/Article6/001-95762.txt
# test_violations/Article6/001-96357.txt
# test_violations/Article6/001-97930.txt
# test_violations/Article8/001-57905.txt
# test_violations/Article6/001-79474.txt
# train/Article6/both/001-57479.txt
# test_violations/Article3/001-119951.txt
# test_violations/Article6/001-86581.txt
# test_violations/Article6/001-148268.txt
# test_violations/Article6/001-95351.txt
# train/Article8/non-violation/001-161527.txt
# train/Article5/both/001-81400.txt
# test20/Article3/non-violation/001-157325.txt
# test_violations/Article6/001-60428.txt
# test_violations/Article3/001-110440.txt
# test_violations/Article2/001-88777.txt
# train/Article6/non-violation/001-159071.txt
# test_violations/Article6/001-97999.txt
# test_violations/Article6/001-57453.txt
# train/Article6/both/001-107026.txt
# train/Article6/non-violation/001-141947.txt
# test_violations/Article6/001-60839.txt
# train/Article4/both/001-114032.txt
# test_violations/Article10/001-111421.txt
# test_violations/Article5/001-82309.txt
# train/Article3/violation/001-170704.txt
# test_violations/Article13/001-126539.txt
# train/Article6/non-violation/001-163114.txt
# test_violations/Article13/001-61854.txt
# test_violations/Article5/001-103390.txt
# test_violations/Article5/001-115302.txt
# test_violations/Article13/001-126633.txt
# train/Article6/violation/001-88677.txt
# test_violations/Article6/001-88375.txt
# test_violations/Article6/001-60017.txt
# test_violations/Article6/001-79194.txt
# train/Article6/violation/001-98515.txt
# train/Article6/non-violation/001-57672.txt
# train/Article14/violation/001-96020.txt
# test_violations/Article6/001-103663.txt
# test_violations/Article3/001-119671.txt
# test_violations/Article2/001-68419.txt
# test_violations/Article6/001-95071.txt
# test20/Article6/non-violation/001-76495.txt
# test_violations/Article6/001-92418.txt
# train/Article13/both/001-60738.txt
# train/Article8/violation/001-105758.txt
# test_violations/Article3/001-162207.txt
# test_violations/Article6/001-83331.txt
# test_violations/Article5/001-75900.txt
# test_violations/Article6/001-61659.txt
# train/Article8/violation/001-157695.txt
# train/Article6/violation/001-73258.txt
# train/Article8/non-violation/001-96693.txt
# test_violations/Article13/001-118589.txt
# test_violations/Article6/001-60653.txt
# test_violations/Article5/001-107731.txt
# train/Article3/violation/001-145366.txt
# train/Article3/both/001-81400.txt
# train/Article6/both/001-170655.txt
# test20/Article3/violation/001-68067.txt
# train/Article5/both/001-59367.txt
# train/Article8/violation/001-57767.txt
# train/Article6/violation/001-169466.txt
# test_violations/Article6/001-75698.txt
# test20/Article8/violation/001-58448.txt
# test20/Article3/violation/001-165232.txt
# test_violations/Article8/001-147117.txt
# test_violations/Article6/001-113632.txt
# test_violations/Article2/001-93608.txt
# test_violations/Article5/001-60513.txt
# test_violations/Article6/001-59883.txt
# test_violations/Article6/001-89909.txt
# test_violations/Article9/001-60522.txt
# train/Article3/violation/001-116332.txt
# test20/Article3/non-violation/001-155717.txt
# test_violations/Article13/001-111850.txt
# test20/Article13/violation/001-80733.txt
# test_violations/Article14/001-57563.txt
# train/Article5/non-violation/001-104862.txt
# test20/Article2/violation/001-102943.txt
# test_violations/Article6/001-61379.txt
# train/Article6/violation/001-68512.txt
# test_violations/Article13/001-72549.txt
# test_violations/Article13/001-76270.txt
# test_violations/Article8/001-58987.txt
# test_violations/Article2/001-90813.txt
# test_violations/Article3/001-58900.txt
# test_violations/Article9/001-81195.txt
# train/Article10/non-violation/001-58115.txt
# train/Article8/violation/001-91726.txt
# test_violations/Article5/001-148654.txt
# test_violations/Article6/001-77997.txt
# test_violations/Article5/001-107040.txt
# test_violations/Article8/001-67346.txt
# test_violations/Article5/001-103413.txt
# test_violations/Article6/001-92774.txt
# test_violations/Article3/001-138573.txt
# test_violations/Article18/001-67984.txt
# test_violations/Article6/001-76991.txt
# train/Article8/non-violation/001-146383.txt
# test_violations/Article10/001-58753.txt
# train/Article3/violation/001-164679.txt
# test_violations/Article6/001-81629.txt
# test20/Article13/violation/001-91802.txt
# test20/Article2/non-violation/
# train/Article2/violation/001-69196.txt
# test_violations/Article6/001-75480.txt
# test_violations/Article6/001-78211.txt
# test_violations/Article6/001-80529.txt
# test_violations/Article6/001-69030.txt
# test20/Article6/violation/001-76463.txt
# test_violations/Article6/001-61099.txt
# train/Article5/violation/001-108654.txt
# train/Article2/violation/001-115887.txt
# train/Article5/non-violation/001-61875.txt
# train/Article13/violation/001-87227.txt
# test_violations/Article6/001-57701.txt
# test20/Article8/non-violation/001-98688.txt
# test_violations/Article5/001-59052.txt
# test_violations/Article6/001-87966.txt
# train/Article3/both/001-94837.txt
# train/Article3/non-violation/001-102953.txt
# test_violations/Article5/001-156076.txt
# test_violations/Article2/001-77396.txt
# test_violations/Article13/001-88476.txt
# test_violations/Article3/001-99399.txt
# train/Article10/non-violation/001-161898.txt
# test20/Article14/violation/001-114513.txt
# test_violations/Article5/001-84684.txt
# test_violations/Article5/001-79713.txt
# test_violations/Article6/001-81822.txt
# test_violations/Article11/001-104794.txt
# test_violations/Article6/001-57832.txt
# train/Article5/non-violation/001-58319.txt
# test_violations/Article9/001-58739.txt
# test_violations/Article5/001-167556.txt
# test_violations/Article6/001-58016.txt
# test_violations/Article6/001-81411.txt
# test_violations/Article6/001-95799.txt
# train/Article8/violation/001-138892.txt
# test_violations/Article6/001-60807.txt
# test_violations/Article13/001-83400.txt
# test_violations/Article13/001-171101.txt
# test_violations/Article5/001-82913.txt
# test_violations/Article3/001-142430.txt
# test_violations/Article6/001-92829.txt
# test_violations/Article6/001-98119.txt
# test_violations/Article3/001-106551.txt
# test_violations/Article6/001-107444.txt
# train/Article6/non-violation/001-57546.txt
# train/Article18/non-violation/001-72236.txt
# test_violations/Article6/001-88343.txt
# test_violations/Article5/001-171101.txt
# test_violations/Article6/001-100395.txt
# test_violations/Article3/001-98909.txt
# test_violations/Article10/001-57708.txt
# test_violations/Article9/001-142739.txt
# test_violations/Article6/001-73367.txt
# test_violations/Article6/001-88529.txt
# test_violations/Article5/001-109881.txt
# test_violations/Article3/001-121957.txt
# test_violations/Article10/001-99775.txt
# test_violations/Article5/001-154025.txt
# test_violations/Article6/001-59215.txt
# test_violations/Article8/001-104662.txt
# test_violations/Article6/001-73181.txt
# train/Article14/non-violation/001-144669.txt
# train/Article6/non-violation/001-88562.txt
# test_violations/Article6/001-76323.txt
# train/Article13/violation/001-68736.txt
# test20/Article3/violation/001-91368.txt
# test_violations/Article6/001-98755.txt
# test_violations/Article3/001-77522.txt
# test_violations/Article9/001-59621.txt
# test_violations/Article5/001-172107.txt
# test_violations/Article6/001-58783.txt
# train/Article2/both/001-110814.txt
# test_violations/Article5/001-88777.txt
# test_violations/Article8/001-150299.txt
# test_violations/Article6/001-77329.txt
# test_violations/Article6/001-79293.txt
# test_violations/Article13/001-150311.txt
# test_violations/Article6/001-101594.txt
# test_violations/Article6/001-68148.txt
# train/Article10/violation/001-67392.txt
# test_violations/Article13/001-75581.txt
# test_violations/Article6/001-78902.txt
# test_violations/Article6/001-61758.txt
# test_violations/Article6/001-77802.txt
# test_violations/Article10/001-107307.txt
# test_violations/Article5/001-107768.txt
# test_violations/Article6/001-61889.txt
# test_violations/Article13/001-94127.txt
# test_violations/Article11/001-89558.txt
# train/Article11/violation/001-175668.txt
# train/Article10/non-violation/001-58905.txt
# test20/Article3/violation/001-99430.txt
# train/Article8/both/001-84375.txt
# test_violations/Article9/001-90755.txt
# train/Article6/both/001-86729.txt
# test_violations/Article2/001-118601.txt
# test_violations/Article13/001-93121.txt
# train/Article13/violation/001-89060.txt
# test_violations/Article11/001-91938.txt
# test_violations/Article8/001-57887.txt
# test20/Article5/non-violation/001-172665.txt
# test_violations/Article6/001-60752.txt
# test_violations/Article6/001-61820.txt
# test_violations/Article6/001-93748.txt
# train/Article6/violation/001-100989.txt
# test_violations/Article6/001-88809.txt
# train/Article6/non-violation/001-173788.txt
# train/Article3/both/001-102235.txt
# train/Article6/non-violation/001-142423.txt
# test_violations/Article8/001-58039.txt
# test_violations/Article2/001-59562.txt
# train/Article6/non-violation/001-59154.txt
# train/Article3/violation/001-108761.txt
# test_violations/Article5/001-93608.txt
# train/Article6/violation/001-67986.txt
# test_violations/Article6/001-59098.txt
# test20/Article14/violation/001-119968.txt
# test_violations/Article13/001-92595.txt
# train/Article5/both/001-61940.txt
# train/Article8/non-violation/001-61963.txt
# train/Article6/non-violation/001-60466.txt
# test20/Article7/violation/
# train/Article8/violation/001-60019.txt
# test20/Article6/non-violation/001-57467.txt
# train/Article8/violation/001-107713.txt
# test20/Article6/non-violation/001-57972.txt
# test_violations/Article13/001-93252.txt
# train/Article3/both/001-110541.txt
# train/Article6/both/001-61660.txt
# test_violations/Article3/001-87622.txt
# test20/Article6/non-violation/001-104702.txt
# test20/Article6/non-violation/001-57561.txt
# test_violations/Article6/001-94979.txt
# train/Article8/non-violation/001-114492.txt
# test_violations/Article6/001-87094.txt
# train/Article14/non-violation/001-60979.txt
# train/Article14/violation/001-93854.txt
# test_violations/Article6/001-108418.txt
# train/Article3/violation/001-70685.txt
# test_violations/Article6/001-61540.txt
# train/Article2/both/001-69616.txt
# test_violations/Article13/001-106668.txt
# ...
# train/Article5/non-violation/001-58120.txt
# test_violations/Article3/001-98182.txt
# test_violations/Article5/001-101923.txt
# test_violations/Article6/001-96195.txt
# test_violations/Article5/001-100033.txt
# train/Article6/non-violation/001-59453.txt
# test_violations/Article3/001-105277.txt
# test_violations/Article3/001-120970.txt
# test_violations/Article6/001-77821.txt
# test_violations/Article5/001-97155.txt
# test_violations/Article6/001-78416.txt
# test20/Article5/violation/001-111418.txt
# test_violations/Article8/001-128053.txt
# test_violations/Article9/001-75997.txt
# train/Article5/both/001-127107.txt
# test_violations/Article6/001-91057.txt
# test20/Article14/violation/001-91096.txt
# test_violations/Article3/001-145442.txt
# test20/Article6/non-violation/001-57766.txt
# test_violations/Article2/001-59450.txt
# test_violations/Article5/001-163799.txt
# test_violations/Article13/001-103251.txt
# test_violations/Article5/001-122185.txt
# test_violations/Article10/001-58104.txt
# test_violations/Article13/001-112021.txt
# test_violations/Article6/001-61366.txt
# test_violations/Article6/001-71615.txt
# test_violations/Article6/001-89056.txt
# test20/Article8/violation/001-150800.txt
# test_violations/Article5/001-91422.txt
# test_violations/Article5/001-80073.txt
# test_violations/Article5/001-156249.txt
# test_violations/Article6/001-71204.txt
# test_violations/Article6/001-107238.txt
# test_violations/Article6/001-94867.txt
# test_violations/Article6/001-105164.txt
# train/Article8/violation/001-91302.txt
# test_violations/Article6/001-78547.txt
# test_violations/Article6/001-86249.txt
# train/Article6/non-violation/001-60896.txt
# test_violations/Article6/001-85654.txt
# train/Article8/non-violation/001-57606.txt
# test_violations/Article6/001-59590.txt
# test_violations/
# test_violations/Article2/001-145224.txt
# test20/Article10/non-violation/001-128039.txt
# test_violations/Article5/001-145708.txt
# train/Article8/non-violation/001-109572.txt
# test_violations/Article5/001-113718.txt
# test_violations/Article6/001-71335.txt
# test_violations/Article6/001-61086.txt
# test_violations/Article5/001-87402.txt
# test_violations/Article8/001-82179.txt
# train/Article6/non-violation/001-91880.txt
# test_violations/Article6/001-86885.txt
# test_violations/Article13/001-144142.txt
# train/Article13/both/001-68670.txt
# test_violations/Article6/001-71498.txt
# train/Article6/violation/001-88818.txt
# train/Article6/non-violation/001-95300.txt
# test_violations/Article3/001-117134.txt
# test_violations/Article6/001-72977.txt
# train/Article6/non-violation/001-94200.txt
# test_violations/Article6/001-164449.txt
# test_violations/Article13/001-68959.txt
# train/Article5/non-violation/001-78159.txt
# train/Article6/both/001-173798.txt
# test_violations/Article6/001-127619.txt
# train/Article13/non-violation/001-60896.txt
# train/Article5/violation/001-57439.txt
# test_violations/Article10/001-164668.txt
# test_violations/Article6/001-163443.txt
# test_violations/Article6/001-170045.txt
# test_violations/Article8/001-118332.txt
# test_violations/Article13/001-145784.txt
# train/Article3/non-violation/001-69022.txt
# train/Article2/non-violation/001-150676.txt
# train/Article14/non-violation/001-76762.txt
# test_violations/Article5/001-104668.txt
# test_violations/Article5/001-89607.txt
# test_violations/Article6/001-98928.txt
# test_violations/Article5/001-106425.txt
# train/Article5/non-violation/001-61582.txt
# test_violations/Article8/001-156267.txt
# test_violations/Article5/001-167100.txt
# test20/Article6/violation/001-78375.txt
# train/Article8/violation/001-90590.txt
# test_violations/Article9/001-71461.txt
# test_violations/Article9/001-98829.txt
# test_violations/Article8/001-93310.txt
# test_violations/Article6/001-82946.txt
# test_violations/Article13/001-140235.txt
# train/Article14/violation/001-71983.txt
# train/Article8/violation/001-127229.txt
# test_violations/Article6/001-81972.txt
# train/Article8/non-violation/001-57551.txt
# test20/Article3/non-violation/001-61634.txt
# test_violations/Article9/001-145790.txt
# train/Article13/non-violation/001-94200.txt
# train/Article6/violation/001-57779.txt
# test_violations/Article9/001-170343.txt
# train/Article6/violation/001-160259.txt
# test_violations/Article6/001-83603.txt
# train/Article6/non-violation/001-87892.txt
# test_violations/Article5/001-104893.txt
# train/Article3/non-violation/001-58008.txt
# test_violations/Article13/001-100263.txt
# test_violations/Article6/001-88399.txt
# train/Article6/violation/001-116827.txt
# train/Article5/both/001-57597.txt
# test_violations/Article18/001-79486.txt
# train/Article10/violation/001-102412.txt
# test_violations/Article2/001-60505.txt
# train/Article5/non-violation/001-72240.txt
# test_violations/Article6/001-157698.txt
# test_violations/Article13/001-61940.txt
# train/Article7/non-violation/001-97963.txt
# test_violations/Article9/001-164467.txt
# test_violations/Article6/001-105823.txt
# train/Article3/violation/001-114468.txt
# test_violations/Article6/001-90368.txt
# test_violations/Article6/001-89150.txt
# test_violations/Article8/001-153017.txt
# train/Article6/non-violation/001-111837.txt
# train/Article5/violation/001-161408.txt
# train/Article11/non-violation/001-57515.txt
# test_violations/Article6/001-76721.txt
# test_violations/Article2/001-142516.txt
# test_violations/Article6/001-75242.txt
# test_violations/Article6/001-61745.txt
# test_violations/Article9/001-68920.txt
# train/Article3/both/001-172459.txt
# test_violations/Article9/001-173779.txt
# test_violations/Article6/001-104886.txt
# test_violations/Article8/001-91608.txt
# test_violations/Article5/001-145784.txt
# test_violations/Article5/001-146379.txt
# test_violations/Article6/001-70104.txt
# test_violations/Article6/001-77858.txt
# test_violations/Article5/001-60537.txt
# test_violations/Article5/001-162761.txt
# train/Article3/both/001-141668.txt
# test_violations/Article3/001-93012.txt
# test_violations/Article6/001-67198.txt
# test_violations/Article6/001-82891.txt
# train/Article6/violation/001-92526.txt
# test20/Article6/violation/001-59884.txt
# test_violations/Article6/001-90182.txt
# test_violations/Article6/001-61876.txt
# test_violations/Article8/001-108710.txt
# train/Article10/non-violation/001-59207.txt
# test_violations/Article6/001-99188.txt
# test_violations/Article6/001-60870.txt
# test_violations/Article11/001-148286.txt
# test_violations/Article2/001-98173.txt
# test_violations/Article6/001-77578.txt
# train/Article10/both/001-102965.txt
# train/Article3/both/001-158027.txt
# test_violations/Article9/001-90051.txt
# test_violations/Article6/001-87448.txt
# train/Article3/violation/001-80921.txt
# test_violations/Article6/001-96218.txt
# test_violations/Article6/001-92387.txt
# train/Article3/non-violation/001-173802.txt
# test_violations/Article6/001-84274.txt
# test20/Article11/non-violation/001-59617.txt
# train/Article14/violation/001-122375.txt
# test20/Article6/violation/001-94438.txt
# test_violations/Article6/001-87005.txt
# test_violations/Article6/001-77261.txt
# train/Article6/violation/001-90583.txt
# test_violations/Article6/001-57725.txt
# test_violations/Article6/001-87579.txt
# test_violations/Article6/001-70871.txt
# test_violations/Article5/001-90173.txt
# train/Article6/non-violation/001-144367.txt
# train/Article6/violation/001-72804.txt
# test_violations/Article6/001-70460.txt
# test_violations/Article3/001-78591.txt
# test_violations/Article13/001-90400.txt
# test_violations/Article9/001-57626.txt
# test_violations/Article6/001-97417.txt
# test_violations/Article9/001-105561.txt
# train/Article14/violation/001-86454.txt
# train/Article8/non-violation/001-71988.txt
# test_violations/Article13/001-89568.txt
# train/Article5/both/001-58913.txt
# train/Article14/violation/001-161061.txt
# test_violations/Article13/001-96675.txt
# test_violations/Article13/001-99911.txt
# test_violations/Article6/001-81940.txt
# test_violations/Article13/001-159791.txt
# train/Article10/violation/001-76714.txt
# test_violations/Article5/001-160616.txt
# test_violations/Article6/001-71597.txt
# train/Article3/both/001-128056.txt
# test20/Article13/non-violation/001-111837.txt
# test_violations/Article6/001-59519.txt
# test20/Article6/non-violation/001-122429.txt
# train/Article5/violation/001-83081.txt
# train/Article3/violation/001-88673.txt
# train/Article5/non-violation/001-110948.txt
# train/Article5/both/001-114249.txt
# test_violations/Article8/001-126133.txt
# test_violations/Article6/001-59613.txt
# train/Article6/violation/001-72935.txt
# test_violations/Article6/001-82503.txt
# test_violations/Article11/001-85489.txt
# test_violations/Article13/001-91126.txt
# test_violations/Article6/001-127812.txt
# test_violations/Article2/001-90800.txt
# test_violations/Article6/001-60925.txt
# test_violations/Article13/001-99569.txt
# train/Article14/non-violation/001-57509.txt
# test_violations/Article5/001-160430.txt
# test_violations/Article6/001-79597.txt
# test_violations/Article3/001-61121.txt
# test_violations/Article6/001-73042.txt
# test_violations/Article6/001-139272.txt
# test_violations/Article6/001-80498.txt
# train/Article6/non-violation/001-169475.txt
# test_violations/Article6/001-90779.txt
# test_violations/Article10/001-127115.txt
# test_violations/Article6/001-72890.txt
# test_violations/Article6/001-58265.txt
# test_violations/Article6/001-95063.txt
# test_violations/Article6/001-155087.txt
# train/Article6/non-violation/001-88997.txt
# train/Article5/non-violation/001-93292.txt
# test_violations/Article6/001-80087.txt
# test_violations/Article8/001-79769.txt
# train/Article6/non-violation/001-147865.txt
# test_violations/Article6/001-90336.txt
# test_violations/Article6/001-57670.txt
# test_violations/Article13/001-68840.txt
# test_violations/Article8/001-89607.txt
# test_violations/Article13/001-78205.txt
# test_violations/Article13/001-82581.txt
# test_violations/Article6/001-116594.txt
# test_violations/Article5/001-78040.txt
# test20/Article14/violation/
# train/Article6/non-violation/001-59869.txt
# train/Article3/both/001-113273.txt
# train/Article6/violation/001-70581.txt
# test_violations/Article13/001-71815.txt
# test20/Article14/non-violation/001-94204.txt
# test_violations/Article9/001-157964.txt
# train/Article11/violation/001-110263.txt
# test_violations/Article5/001-141434.txt
# test_violations/Article6/001-67988.txt
# train/Article8/violation/001-160219.txt
# test_violations/Article6/001-76758.txt
# test_violations/Article5/001-60505.txt
# train/Article5/non-violation/001-109581.txt
# test_violations/Article13/001-86449.txt
# train/Article3/both/001-87350.txt
# test_violations/Article10/001-57925.txt
# test_violations/Article13/001-91893.txt
# test_violations/Article6/001-83454.txt
# test_violations/Article8/001-95777.txt
# test_violations/Article6/001-59053.txt
# test20/Article2/non-violation/001-175144.txt
# test_violations/Article6/001-83043.txt
# test_violations/Article9/001-67478.txt
# test_violations/Article8/001-79583.txt
# test_violations/Article6/001-153316.txt
# test_violations/Article6/001-93866.txt
# test_violations/Article3/001-162424.txt
# test_violations/Article14/001-58212.txt
# train/Article13/violation/001-68953.txt
# train/Article6/non-violation/001-59589.txt
# test_violations/Article5/001-88583.txt
# test_violations/Article5/001-162860.txt
# test_violations/Article6/001-94429.txt
# test_violations/Article9/001-114517.txt
# train/Article3/violation/001-76341.txt
# train/Article10/non-violation/001-119244.txt
# test_violations/Article6/001-104574.txt
# test20/Article6/non-violation/001-164202.txt
# train/Article4/non-violation/001-57591.txt
# train/Article3/both/001-158500.txt
# test_violations/Article6/001-92766.txt
# train/Article5/both/001-108697.txt
# train/Article10/non-violation/001-158279.txt
# test_violations/Article9/001-61334.txt
# test_violations/Article13/001-103387.txt
# test_violations/Article13/001-79156.txt
# test_violations/Article6/001-79303.txt
# test_violations/Article9/001-103230.txt
# train/Article3/violation/001-93798.txt
# test_violations/Article6/001-85310.txt
# train/Article11/non-violation/001-112101.txt
# train/Article8/non-violation/001-109577.txt
# train/Article6/non-violation/001-173463.txt
# test_violations/Article9/001-77447.txt
# train/Article6/non-violation/001-158243.txt
# test_violations/Article6/001-69022.txt
# test_violations/Article6/001-93997.txt
# train/Article2/non-violation/001-68548.txt
# test_violations/Article13/001-77050.txt
# test_violations/Article6/001-99792.txt
# test_violations/Article13/001-70187.txt
# test_violations/Article5/001-156068.txt
# train/Article5/both/001-163671.txt
# train/Article6/non-violation/001-142672.txt
# train/Article6/violation/001-107185.txt
# test_violations/Article13/001-80025.txt
# train/Article5/non-violation/001-100504.txt
# test_violations/Article13/001-73012.txt
# test_violations/Article13/001-98717.txt
# train/Article5/both/001-70865.txt
# test_violations/Article5/001-103125.txt
# train/Article8/non-violation/001-100197.txt
# test_violations/Article9/001-71303.txt
# test_violations/Article6/001-79434.txt
# test_violations/Article9/001-61054.txt
# test_violations/Article6/001-86036.txt
# test_violations/Article2/001-104662.txt
# test_violations/Article3/001-111406.txt
# train/Article6/violation/001-78225.txt
# test_violations/Article13/001-100548.txt
# test_violations/Article5/001-155193.txt
# test_violations/Article9/001-77672.txt
# train/Article8/violation/001-89283.txt
# test_violations/Article9/001-87510.txt
# test_violations/Article6/001-72633.txt
# test_violations/Article18/001-61963.txt
# train/Article14/violation/001-161982.txt
# train/Article3/violation/001-93580.txt
# train/Article7/non-violation/001-119066.txt
# train/Article6/violation/001-60991.txt
# test_violations/Article5/001-103350.txt
# test_violations/Article8/001-92752.txt
# test_violations/Article13/001-73143.txt
# train/Article14/violation/001-100042.txt
# test_violations/Article6/001-96953.txt
# train/Article8/non-violation/001-57967.txt
# train/Article14/violation/001-69670.txt
# test_violations/Article6/001-100798.txt
# train/Article3/violation/001-90610.txt
# test_violations/Article3/001-59338.txt
# test_violations/Article6/001-96037.txt
# test_violations/Article5/001-121563.txt
# test_violations/Article6/001-100387.txt
# test_violations/Article13/001-98026.txt
# test_violations/Article5/001-93577.txt
# test_violations/Article6/001-90747.txt
# test_violations/Article3/001-148286.txt
# test_violations/Article3/001-111631.txt
# test_violations/Article6/001-95031.txt
# train/Article5/both/001-104983.txt
# test_violations/Article8/001-142520.txt
# test_violations/Article13/001-92325.txt
# train/Article3/violation/001-58987.txt
# test_violations/Article6/001-90304.txt
# test20/Article6/violation/001-81922.txt
# test_violations/Article8/001-105217.txt
# train/Article14/violation/001-172135.txt
# train/Article10/non-violation/001-60974.txt
# test_violations/Article3/001-173475.txt
# test_violations/Article5/001-114456.txt
# test_violations/Article6/001-89566.txt
# test_violations/Article6/001-109044.txt
# test_violations/Article6/001-96673.txt
# test20/Article3/violation/001-91422.txt
# test_violations/Article2/001-102007.txt
# test_violations/Article13/001-98662.txt
# test_violations/Article10/001-140771.txt
# test_violations/Article6/001-105006.txt
# test_violations/Article6/001-67956.txt
# test20/Article5/non-violation/001-57506.txt
# test_violations/Article8/001-57810.txt
# test_violations/Article6/001-171474.txt
# test_violations/Article11/001-162211.txt
# train/Article2/non-violation/001-161975.txt
# test_violations/Article6/001-126974.txt
# test_violations/Article6/001-156254.txt
# test_violations/Article6/001-75247.txt
# test_violations/Article5/001-106786.txt
# train/Article10/non-violation/001-174404.txt
# test_violations/Article13/001-75573.txt
# test_violations/Article14/001-72238.txt
# test_violations/Article6/001-59432.txt
# test_violations/Article6/001-81254.txt
# test_violations/Article6/001-73173.txt
# test20/Article6/non-violation/001-57833.txt
# test20/Article14/violation/001-71627.txt
# test_violations/Article6/001-61339.txt
# test_violations/Article6/001-97399.txt
# test_violations/Article5/001-90800.txt
# train/Article11/non-violation/001-93475.txt
# train/Article14/non-violation/001-58901.txt
# test_violations/Article6/001-88691.txt
# test20/Article5/non-violation/001-57637.txt
# train/Article14/non-violation/001-60808.txt
# train/Article2/violation/001-115305.txt
# test20/Article3/violation/001-160628.txt
# test_violations/Article5/001-98832.txt
# test_violations/Article2/001-92725.txt
# train/Article6/non-violation/001-104549.txt

# %%
#all necessary imports
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
import glob,re, os, sys, random
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_recall_fscore_support
from nltk.corpus import stopwords
from random import shuffle

# %%
def extract_text(starts, ends, cases, violation):
    facts = []
    D = []
    years = []
    for case in cases:
        contline = ''
        year = 0
        with open(case, 'r') as f:
            for line in f:
                dat = re.search('^([0-9]{1,2}\s\w+\s([0-9]{4}))', line)
                if dat != None:
                    year = int(dat.group(2))
                    break
            if year>0:
                years.append(year)
                wr = 0
                for line in f:
                    if wr == 0:
                        if re.search(starts, line) != None:
                            wr = 1
                    if wr == 1 and re.search(ends, line) == None:
                        contline += line
                        contline += '\n'
                    elif re.search(ends, line) != None:
                        break
                facts.append(contline)
    for i in range(len(facts)):
        D.append((facts[i], violation, years[i])) 
    return D

# %%
def extract_parts(train_path, violation, part): #extract text from different parts
    cases = glob.glob(train_path)

    facts = []
    D = []
    years = []
    
    if part == 'relevant_law': #seprarte extraction for relevant law
        for case in cases:
            year = 0
            contline = ''
            with open(case, 'r') as f:
                for line in f:
                    dat = re.search('^([0-9]{1,2}\s\w+\s([0-9]{4}))', line)
                    if dat != None:
                        year = int(dat.group(2))
                        break
                if year> 0:
                    years.append(year)
                    wr = 0
                    for line in f:
                        if wr == 0:
                            if re.search('RELEVANT', line) != None:
                                wr = 1
                        if wr == 1 and re.search('THE LAW', line) == None and re.search('PROCEEDINGS', line) == None:
                            contline += line
                            contline += '\n'
                        elif re.search('THE LAW', line) != None or re.search('PROCEEDINGS', line) != None:
                            break
                    facts.append(contline)
        for i in range(len(facts)):
            D.append((facts[i], violation, years[i]))
        
    if part == 'facts':
        starts = 'THE FACTS'
        ends ='THE LAW'
        D = extract_text(starts, ends, cases, violation)
    if part == 'circumstances':
        starts = 'CIRCUMSTANCES'
        ends ='RELEVANT'
        D = extract_text(starts, ends, cases, violation)
    if part == 'procedure':
        starts = 'PROCEDURE'
        ends ='THE FACTS'
        D = extract_text(starts, ends, cases, violation)
    if part == 'procedure+facts':
        starts = 'PROCEDURE'
        ends ='THE LAW'
        D = extract_text(starts, ends, cases, violation)
    return D

# %%
def train_model_cross_val(Xtrain, Ytrain, vec, c): #Linear SVC model cross-validation
    print('***10-fold cross-validation***')
    pipeline = Pipeline([
        ('features', FeatureUnion(
            [vec],
        )),
        ('classifier', LinearSVC(C=c))
        ])
    Ypredict = cross_val_predict(pipeline, Xtrain, Ytrain, cv=10) #10-fold cross-validation
    evaluate(Ytrain, Ypredict)

# %%
def train_model_test(Xtrain, Ytrain, Xtest_v, Ytest_v, vec, c): #test on 'violations' test set
    pipeline = Pipeline([
        ('features', FeatureUnion([vec]
        )),
        ('classifier', LinearSVC(C=c))
        ])
    pipeline.fit(Xtrain, Ytrain)
    print('***testing on violation testset***')
    Ypredict = pipeline.predict(Xtest_v)
    evaluate(Ytest_v, Ypredict)

# %%
def evaluate(Ytest, Ypredict): #evaluate the model (accuracy, precision, recall, f-score, confusion matrix)
        print('Accuracy:', accuracy_score(Ytest, Ypredict) )
        print('\nClassification report:\n', classification_report(Ytest, Ypredict))
        print('\nCR:', precision_recall_fscore_support(Ytest, Ypredict, average='macro'))
        print('\nConfusion matrix:\n', confusion_matrix(Ytest, Ypredict), '\n\n_______________________\n\n')

# %%
def run_pipeline(part, vec, c): #run tests
    
    print('Trained on *' + part + '* part of the cases')
    
    v = extract_parts(path+'train/'+article+'/violation/*.txt', 'violation', part)
    nv = extract_parts(path+'train/'+article+'/non-violation/*.txt', 'non-violation', part)
    trainset =v+nv
    print(trainset)
    shuffle(trainset)

    Xtrain = [i[0] for i in trainset]
    Ytrain = [i[1] for i in trainset]
    
    #test set with violations only
    if article == 'Article14':
        test = extract_parts('./test_violations/'+article+'/*.txt', 'non-violation', part)
    else:
        test = extract_parts('./test_violations/'+article+'/*.txt', 'violation', part)
    Xtest_v = [i[0] for i in test]
    Ytest_v = [i[1] for i in test]


    print('Training on', Ytrain.count('violation'),'+', Ytrain.count('non-violation'), '=', Ytrain.count('violation') + Ytrain.count('non-violation'), 'cases', '\nCases available for testing(violation):', Ytest_v.count('violation'))
    #train_model_test(Xtrain, Ytrain, Xtest_v, Ytest_v, vec, c)
    train_model_cross_val(Xtrain, Ytrain, vec, c) #use for cross-validation

# %%
if __name__ == "__main__":
    ##INDICATE THE PATH TO THE DATA
    #path = '~/Documents/ECtHR_crystal_ball/'
    path = '/content/'
    articles = ['Article2', 'Article3', 'Article5', 'Article6', 'Article8', 'Article10', 'Article11', 'Article13', 'Article14']
    for article in articles: #the parameters were determined using grid-search
        print (article)
        if article == 'Article2':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', ngram_range = (3,4), binary = False, lowercase = True, min_df = 2, norm = 'l2', stop_words = None, use_idf = True))
            c = 0.1
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article3':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (1,1),  norm = None,  stop_words = None,  use_idf = True))
            c = 0.1
            run_pipeline('facts', vec, c)
        if article == 'Article5':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 1
            run_pipeline('facts', vec, c) 
        if article == 'Article6':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 2,  ngram_range = (2,4),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article8':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (3, 3),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 1
            run_pipeline('facts', vec, c)
        if article == 'Article10':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = False,  min_df = 1,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article11':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 2,  ngram_range = (1, 1),  norm = 'l1',  stop_words = 'english',  use_idf = False))
            c = 1
            run_pipeline('procedure', vec, c)
        if article == 'Article13':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 1,  ngram_range = (1, 2),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article14':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = 'english',  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 57 + 57 = 114 cases
# Cases available for testing(violation): 398
# ***10-fold cross-validation***
# Accuracy: 0.7543859649122807
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.74      0.79      0.76        57
#     violation       0.77      0.72      0.75        57
#
#      accuracy                           0.75       114
#     macro avg       0.76      0.75      0.75       114
#  weighted avg       0.76      0.75      0.75       114
#
#
# CR: (0.7556449118465822, 0.7543859649122807, 0.7540832049306626, None)
#
# Confusion matrix:
#  [[45 12]
#  [16 41]]
#
# _______________________
#
#
# Article3
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 284 + 284 = 568 cases
# Cases available for testing(violation): 851
# ***10-fold cross-validation***
# Accuracy: 0.7975352112676056
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.81      0.77      0.79       284
#     violation       0.78      0.82      0.80       284
#
#      accuracy                           0.80       568
#     macro avg       0.80      0.80      0.80       568
#  weighted avg       0.80      0.80      0.80       568
#
#
# CR: (0.7981599512964827, 0.7975352112676056, 0.7974290986339179, None)
#
# Confusion matrix:
#  [[220  64]
#  [ 51 233]]
#
# _______________________
#
#
# Article5
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 150 + 150 = 300 cases
# Cases available for testing(violation): 1118
# ***10-fold cross-validation***
# Accuracy: 0.7566666666666667
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.76      0.75      0.75       150
#     violation       0.75      0.77      0.76       150
#
#      accuracy                           0.76       300
#     macro avg       0.76      0.76      0.76       300
#  weighted avg       0.76      0.76      0.76       300
#
#
# CR: (0.7567693744164332, 0.7566666666666667, 0.7566423308997567, None)
#
# Confusion matrix:
#  [[112  38]
#  [ 35 115]]
#
# _______________________
#
#
# Article6
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 458 + 458 = 916 cases
# Cases available for testing(violation): 4092
# ***10-fold cross-validation***
# Accuracy: 0.8067685589519651
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.78      0.86      0.82       458
#     violation       0.85      0.75      0.80       458
#
#      accuracy                           0.81       916
#     macro avg       0.81      0.81      0.81       916
#  weighted avg       0.81      0.81      0.81       916
#
#
# CR: (0.8106201396967605, 0.8067685589519651, 0.8061676958114901, None)
#
# Confusion matrix:
#  [[395  63]
#  [114 344]]
#
# _______________________
#
#
# Article8
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 106 + 106 = 212 cases
# Cases available for testing(violation): 252
# ***10-fold cross-validation***
# Accuracy: 0.6415094339622641
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.63      0.68      0.65       106
#     violation       0.65      0.60      0.63       106
#
#      accuracy                           0.64       212
#     macro avg       0.64      0.64      0.64       212
#  weighted avg       0.64      0.64      0.64       212
#
#
# CR: (0.6423200859291085, 0.6415094339622641, 0.6409982174688056, None)
#
# Confusion matrix:
#  [[72 34]
#  [42 64]]
#
# _______________________
#
#
# Article11
# Trained on *procedure* part of the cases
# [('PROCEDURE\n\n1.\xa0\xa0The case was referred to the Court by the European Commission of Human Rights (“the Commission”) on 28 October 1996, within the three-month period laid down by Article 32 § 1 and Article 47 of the Convention for the Protection of Human Rights and Fundamental Freedoms (“the Convention”). It originated in an application (no. 19392/92) against the Republic of Turkey lodged with the Commission under Article 25 by a political party, the United Communist Party of Turkey, and two Turkish nationals, Mr Nihat Sargın and Mr Nabi Yağcı, on 7 January 1992.\n\nThe Commission’s request referred to Articles 44 and 48 (a) of the Convention and to Rule 32 of Rules of Court A. The object of the request was to obtain a decision as to whether the facts of the case disclosed a breach by the respondent State of its obligations under Article 11 of the Convention.\n\n2.\xa0\xa0In response to the enquiry made in accordance with Rule 33 § 3 (d), the applicants stated that they wished to take part in the proceedings and designated the lawyers who would represent them (Rule\xa030). The lawyers were given leave by the President to use the Turkish language in the written and oral stages of the proceedings (Rule 27 § 3).\n\n3.\xa0\xa0The Chamber to be constituted included ex officio Mr F. Gölcüklü, the elected judge of Turkish nationality (Article 43 of the Convention), and Mr\xa0R.\xa0Ryssdal, the President of the Court (Rule 21 § 4 (b)). On 29 October 1996, in the presence of the Registrar, the President drew by lot the names of the other seven members, namely Mr B. Walsh, Mr C. Russo, Mr\xa0I.\xa0Foighel, Mr A.N. Loizou, Mr J. Makarczyk, Mr P. Kūris and Mr\xa0P.\xa0van Dijk (Article 43 in fine of the Convention and Rule 21 § 5).\n\n4.\xa0\xa0As President of the Chamber (Rule 21 § 6), Mr Ryssdal, acting through the Registrar, consulted the Agent of the Turkish Government (“the Government”), the applicants’ lawyers and the Delegate of the Commission on the organisation of the proceedings (Rules 37 § 1 and 38). Pursuant to the order made in consequence, the Registrar received the applicants’ memorial on 3 June 1997 and the Government’s memorial on 18 June.\n\n5.\xa0\xa0On 28 August 1997 the Chamber decided to relinquish jurisdiction forthwith in favour of a Grand Chamber (Rule 51). The Grand Chamber to be constituted included ex officio Mr Ryssdal, the President of the Court, and Mr R. Bernhardt, the Vice-President, together with the members and the four substitutes of the original Chamber, the latter being Mr A.B. Baka, Mr\xa0M.A. Lopes Rocha, Mr R. Pekkanen and Mr\xa0R.\xa0Macdonald (Rule 51 §\xa02\xa0(a) and (b)). On the same day the President, in the presence of the Registrar, drew by lot the names of the seven additional members needed to complete the Grand Chamber, namely Mr\xa0F.\xa0Matscher, Mr N. Valticos, Mrs\xa0E. Palm, Mr J.M. Morenilla, Sir\xa0John\xa0Freeland, Mr L. Wildhaber and Mr U. Lōhmus (Rule 51§\xa02 (c)). Subsequently Mr\xa0Ryssdal and Mr Walsh were unable to take part in the further consideration of the case (Rules 24 §\xa01 and 51 § 3). Mr Ryssdal’s place as President of the Grand Chamber was taken by Mr\xa0Bernhardt (Rules\xa021 § 6 and 51 § 6).\n\n6.\xa0\xa0In accordance with the President’s decision, the hearing took place in public in the Human Rights Building, Strasbourg, on 23 September 1997. The Court had held a preparatory meeting beforehand.\n\n\n\nThere appeared before the Court:\n\n\t•\tfor the Government\u2028Mr\tA. Gündüz, Professor of International Law,\u2028\t\t\tUniversity of Marmara,\tAgent,\u2028Mrs D. Akçay, Deputy Permanent Representative\u2028\t\t\tof Turkey to the Council of Europe,\u2028Mr\tM. Özmen, Ministry of Foreign Affairs,\u2028Mr\tŞ. Alpaslan, Doctor of Law,\u2028Mr\tA. Kaya, Ministry of Justice,\u2028Ms\tA. Emüler, Ministry of Foreign Affairs,\u2028Ms\tY. Renda, Ministry of Foreign Affairs,\u2028Mrs\tN. Ayman, Ministry of the Interior,\u2028Mr\tN. Alkan, Ministry of the Interio ...
# Training on 32 + 32 = 64 cases
# Cases available for testing(violation): 89
# ***10-fold cross-validation***
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 106 + 106 = 212 cases
# Cases available for testing(violation): 1060
# ***10-fold cross-validation***
# Accuracy: 0.839622641509434
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.84      0.84      0.84       106
#     violation       0.84      0.84      0.84       106
#
#      accuracy                           0.84       212
#     macro avg       0.84      0.84      0.84       212
#  weighted avg       0.84      0.84      0.84       212
#
#
# CR: (0.839622641509434, 0.839622641509434, 0.839622641509434, None)
#
# Confusion matrix:
#  [[89 17]
#  [17 89]]
#
# _______________________
#
#
# Article14
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Accuracy: 0.7673611111111112
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.76      0.78      0.77       144
#     violation       0.77      0.76      0.76       144
#
#      accuracy                           0.77       288
#     macro avg       0.77      0.77      0.77       288
#  weighted avg       0.77      0.77      0.77       288
#
#
# CR: (0.7674772036474165, 0.7673611111111112, 0.7673358654367879, None)
#
# Confusion matrix:
#  [[112  32]
#  [ 35 109]]
#
# _______________________

# %%
# Decision Tree model 
from sklearn.tree import DecisionTreeClassifier
def train_model_cross_val(Xtrain, Ytrain, vec, c): #Linear SVC model cross-validation
    print('***10-fold cross-validation***')
    pipeline = Pipeline([
        ('features', FeatureUnion(
            [vec],
        )),
        ('classifier', DecisionTreeClassifier())
        ])
    Ypredict = cross_val_predict(pipeline, Xtrain, Ytrain, cv=10) #10-fold cross-validation
    evaluate(Ytrain, Ypredict)

# %%
def train_model_test(Xtrain, Ytrain, Xtest_v, Ytest_v, vec, c): #test on 'violations' test set
    pipeline = Pipeline([
        ('features', FeatureUnion([vec]
        )),
        ('classifier', DecisionTreeClassifier)
        ])
    pipeline.fit(Xtrain, Ytrain)
    print('***testing on violation testset***')
    Ypredict = pipeline.predict(Xtest_v)
    evaluate(Ytest_v, Ypredict)

# %%
if __name__ == "__main__":
    ##INDICATE THE PATH TO THE DATA
    #path = '~/Documents/ECtHR_crystal_ball/'
    path = '/content/'
    articles = ['Article2', 'Article3', 'Article5', 'Article6', 'Article8', 'Article10', 'Article11', 'Article13', 'Article14']
    for article in articles: #the parameters were determined using grid-search
        print (article)
        if article == 'Article2':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', ngram_range = (3,4), binary = False, lowercase = True, min_df = 2, norm = 'l2', stop_words = None, use_idf = True))
            c = 0.1
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article3':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (1,1),  norm = None,  stop_words = None,  use_idf = True))
            c = 0.1
            run_pipeline('facts', vec, c)
        if article == 'Article5':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 1
            run_pipeline('facts', vec, c) 
        if article == 'Article6':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 2,  ngram_range = (2,4),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article8':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (3, 3),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 1
            run_pipeline('facts', vec, c)
        if article == 'Article10':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = False,  min_df = 1,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article11':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 2,  ngram_range = (1, 1),  norm = 'l1',  stop_words = 'english',  use_idf = False))
            c = 1
            run_pipeline('procedure', vec, c)
        if article == 'Article13':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 1,  ngram_range = (1, 2),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article14':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = 'english',  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 57 + 57 = 114 cases
# Cases available for testing(violation): 398
# ***10-fold cross-validation***
# Accuracy: 0.6403508771929824
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.65      0.60      0.62        57
#     violation       0.63      0.68      0.66        57
#
#      accuracy                           0.64       114
#     macro avg       0.64      0.64      0.64       114
#  weighted avg       0.64      0.64      0.64       114
#
#
# CR: (0.641439205955335, 0.6403508771929824, 0.6396576979415619, None)
#
# Confusion matrix:
#  [[34 23]
#  [18 39]]
#
# _______________________
#
#
# Article3
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 284 + 284 = 568 cases
# Cases available for testing(violation): 851
# ***10-fold cross-validation***
# Accuracy: 0.6461267605633803
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.65      0.65      0.65       284
#     violation       0.65      0.64      0.65       284
#
#      accuracy                           0.65       568
#     macro avg       0.65      0.65      0.65       568
#  weighted avg       0.65      0.65      0.65       568
#
#
# CR: (0.6461285723141776, 0.6461267605633803, 0.6461256637003562, None)
#
# Confusion matrix:
#  [[184 100]
#  [101 183]]
#
# _______________________
#
#
# Article5
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 150 + 150 = 300 cases
# Cases available for testing(violation): 1118
# ***10-fold cross-validation***
# Accuracy: 0.54
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.54      0.55      0.54       150
#     violation       0.54      0.53      0.54       150
#
#      accuracy                           0.54       300
#     macro avg       0.54      0.54      0.54       300
#  weighted avg       0.54      0.54      0.54       300
#
#
# CR: (0.5400071123755334, 0.54, 0.5399795546468731, None)
#
# Confusion matrix:
#  [[82 68]
#  [70 80]]
#
# _______________________
#
#
# Article6
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 458 + 458 = 916 cases
# Cases available for testing(violation): 4092
# ***10-fold cross-validation***
# Accuracy: 0.6572052401746725
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.68      0.59      0.63       458
#     violation       0.64      0.72      0.68       458
#
#      accuracy                           0.66       916
#     macro avg       0.66      0.66      0.66       916
#  weighted avg       0.66      0.66      0.66       916
#
#
# CR: (0.6597674418604651, 0.6572052401746725, 0.6558253519239146, None)
#
# Confusion matrix:
#  [[272 186]
#  [128 330]]
#
# _______________________
#
#
# Article8
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 229 + 229 = 458 cases
# Cases available for testing(violation): 496
# ***10-fold cross-validation***
# Accuracy: 0.5414847161572053
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.56      0.41      0.48       229
#     violation       0.53      0.67      0.59       229
#
#      accuracy                           0.54       458
#     macro avg       0.54      0.54      0.53       458
#  weighted avg       0.54      0.54      0.53       458
#
#
# CR: (0.5443283004258614, 0.5414847161572053, 0.5340116279069768, None)
#
# Confusion matrix:
#  [[ 95 134]
#  [ 76 153]]
#
# _______________________
#
#
# Article10
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Accuracy: 0.5518867924528302
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.55      0.60      0.57       106
#     violation       0.56      0.50      0.53       106
#
#      accuracy                           0.55       212
#     macro avg       0.55      0.55      0.55       212
#  weighted avg       0.55      0.55      0.55       212
#
#
# CR: (0.5524516419253261, 0.5518867924528301, 0.5506771077348682, None)
#
# Confusion matrix:
#  [[64 42]
#  [53 53]]
#
# _______________________
#
#
# Article11
# Trained on *procedure* part of the cases
# [('PROCEDURE\n\n1.\xa0\xa0The case was referred to the Court by the European Commission of Human Rights (“the Commission”) on 28 October 1996, within the three-month period laid down by Article 32 § 1 and Article 47 of the Convention for the Protection of Human Rights and Fundamental Freedoms (“the Convention”). It originated in an application (no. 19392/92) against the Republic of Turkey lodged with the Commission under Article 25 by a political party, the United Communist Party of Turkey, and two Turkish nationals, Mr Nihat Sargın and Mr Nabi Yağcı, on 7 January 1992.\n\nThe Commission’s request referred to Articles 44 and 48 (a) of the Convention and to Rule 32 of Rules of Court A. The object of the request was to obtain a decision as to whether the facts of the case disclosed a breach by the respondent State of its obligations under Article 11 of the Convention.\n\n2.\xa0\xa0In response to the enquiry made in accordance with Rule 33 § 3 (d), the applicants stated that they wished to take part in the proceedings and designated the lawyers who would represent them (Rule\xa030). The lawyers were given leave by the President to use the Turkish language in the written and oral stages of the proceedings (Rule 27 § 3).\n\n3.\xa0\xa0The Chamber to be constituted included ex officio Mr F. Gölcüklü, the elected judge of Turkish nationality (Article 43 of the Convention), and Mr\xa0R.\xa0Ryssdal, the President of the Court (Rule 21 § 4 (b)). On 29 October 1996, in the presence of the Registrar, the President drew by lot the names of the other seven members, namely Mr B. Walsh, Mr C. Russo, Mr\xa0I.\xa0Foighel, Mr A.N. Loizou, Mr J. Makarczyk, Mr P. Kūris and Mr\xa0P.\xa0van Dijk (Article 43 in fine of the Convention and Rule 21 § 5).\n\n4.\xa0\xa0As President of the Chamber (Rule 21 § 6), Mr Ryssdal, acting through the Registrar, consulted the Agent of the Turkish Government (“the Government”), the applicants’ lawyers and the Delegate of the Commission on the organisation of the proceedings (Rules 37 § 1 and 38). Pursuant to the order made in consequence, the Registrar received the applicants’ memorial on 3 June 1997 and the Government’s memorial on 18 June.\n\n5.\xa0\xa0On 28 August 1997 the Chamber decided to relinquish jurisdiction forthwith in favour of a Grand Chamber (Rule 51). The Grand Chamber to be constituted included ex officio Mr Ryssdal, the President of the Court, and Mr R. Bernhardt, the Vice-President, together with the members and the four substitutes of the original Chamber, the latter being Mr A.B. Baka, Mr\xa0M.A. Lopes Rocha, Mr R. Pekkanen and Mr\xa0R.\xa0Macdonald (Rule 51 §\xa02\xa0(a) and (b)). On the same day the President, in the presence of the Registrar, drew by lot the names of the seven additional members needed to complete the Grand Chamber, namely Mr\xa0F.\xa0Matscher, Mr N. Valticos, Mrs\xa0E. Palm, Mr J.M. Morenilla, Sir\xa0John\xa0Freeland, Mr L. Wildhaber and Mr U. Lōhmus (Rule 51§\xa02 (c)). Subsequently Mr\xa0Ryssdal and Mr Walsh were unable to take part in the further consideration of the case (Rules 24 §\xa01 and 51 § 3). Mr Ryssdal’s place as President of the Grand Chamber was taken by Mr\xa0Bernhardt (Rules\xa021 § 6 and 51 § 6).\n\n6.\xa0\xa0In accordance with the President’s decision, the hearing took place in public in the Human Rights Building, Strasbourg, on 23 September 1997. The Court had held a preparatory meeting beforehand.\n\n\n\nThere appeared before the Court:\n\n\t•\tfor the Government\u2028Mr\tA. Gündüz, Professor of International Law,\u2028\t\t\tUniversity of Marmara,\tAgent,\u2028Mrs D. Akçay, Deputy Permanent Representative\u2028\t\t\tof Turkey to the Council of Europe,\u2028Mr\tM. Özmen, Ministry of Foreign Affairs,\u2028Mr\tŞ. Alpaslan, Doctor of Law,\u2028Mr\tA. Kaya, Ministry of Justice,\u2028Ms\tA. Emüler, Ministry of Foreign Affairs,\u2028Ms\tY. Renda, Ministry of Foreign Affairs,\u2028Mrs\tN. Ayman, Ministry of the Interior,\u2028Mr\tN. Alkan, Ministry of the Interio ...
# Training on 32 + 32 = 64 cases
# Cases available for testing(violation): 89
# ***10-fold cross-validation***
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 106 + 106 = 212 cases
# Cases available for testing(violation): 1060
# ***10-fold cross-validation***
# Accuracy: 0.6509433962264151
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.66      0.63      0.64       106
#     violation       0.65      0.67      0.66       106
#
#      accuracy                           0.65       212
#     macro avg       0.65      0.65      0.65       212
#  weighted avg       0.65      0.65      0.65       212
#
#
# CR: (0.6511586452762923, 0.6509433962264151, 0.6508190883190883, None)
#
# Confusion matrix:
#  [[67 39]
#  [35 71]]
#
# _______________________
#
#
# Article14
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Accuracy: 0.6215277777777778
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.62      0.61      0.62       144
#     violation       0.62      0.63      0.63       144
#
#      accuracy                           0.62       288
#     macro avg       0.62      0.62      0.62       288
#  weighted avg       0.62      0.62      0.62       288
#
#
# CR: (0.621580547112462, 0.6215277777777778, 0.6214867064568639, None)
#
# Confusion matrix:
#  [[88 56]
#  [53 91]]
#
# _______________________

# %%
# Random Forest model 
from sklearn.ensemble import RandomForestClassifier
def train_model_cross_val(Xtrain, Ytrain, vec, c): #Linear SVC model cross-validation
    print('***10-fold cross-validation***')
    pipeline = Pipeline([
        ('features', FeatureUnion(
            [vec],
        )),
        ('classifier', RandomForestClassifier())
        ])
    Ypredict = cross_val_predict(pipeline, Xtrain, Ytrain, cv=10) #10-fold cross-validation
    evaluate(Ytrain, Ypredict)

# %%
def train_model_test(Xtrain, Ytrain, Xtest_v, Ytest_v, vec, c): #test on 'violations' test set
    pipeline = Pipeline([
        ('features', FeatureUnion([vec]
        )),
        ('classifier', RandomForestClassifier())
        ])
    pipeline.fit(Xtrain, Ytrain)
    print('***testing on violation testset***')
    Ypredict = pipeline.predict(Xtest_v)
    evaluate(Ytest_v, Ypredict)

# %%
if __name__ == "__main__":
    ##INDICATE THE PATH TO THE DATA
    #path = '~/Documents/ECtHR_crystal_ball/'
    path = '/content/'
    articles = ['Article2', 'Article3', 'Article5', 'Article6', 'Article8', 'Article10', 'Article11', 'Article13', 'Article14']
    for article in articles: #the parameters were determined using grid-search
        print (article)
        if article == 'Article2':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', ngram_range = (3,4), binary = False, lowercase = True, min_df = 2, norm = 'l2', stop_words = None, use_idf = True))
            c = 0.1
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article3':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (1,1),  norm = None,  stop_words = None,  use_idf = True))
            c = 0.1
            run_pipeline('facts', vec, c)
        if article == 'Article5':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 1
            run_pipeline('facts', vec, c) 
        if article == 'Article6':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 2,  ngram_range = (2,4),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article8':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (3, 3),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 1
            run_pipeline('facts', vec, c)
        if article == 'Article10':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = False,  min_df = 1,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article11':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 2,  ngram_range = (1, 1),  norm = 'l1',  stop_words = 'english',  use_idf = False))
            c = 1
            run_pipeline('procedure', vec, c)
        if article == 'Article13':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 1,  ngram_range = (1, 2),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article14':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = 'english',  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
# Out:
# Article2
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 57 + 57 = 114 cases
# Cases available for testing(violation): 398
# ***10-fold cross-validation***
# Accuracy: 0.7105263157894737
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.68      0.81      0.74        57
#     violation       0.76      0.61      0.68        57
#
#      accuracy                           0.71       114
#     macro avg       0.72      0.71      0.71       114
#  weighted avg       0.72      0.71      0.71       114
#
#
# CR: (0.7186700767263428, 0.7105263157894737, 0.7078058252427185, None)
#
# Confusion matrix:
#  [[46 11]
#  [22 35]]
#
# _______________________
#
#
# Article3
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 284 + 284 = 568 cases
# Cases available for testing(violation): 851
# ***10-fold cross-validation***
# Accuracy: 0.772887323943662
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.79      0.74      0.77       284
#     violation       0.76      0.80      0.78       284
#
#      accuracy                           0.77       568
#     macro avg       0.77      0.77      0.77       568
#  weighted avg       0.77      0.77      0.77       568
#
#
# CR: (0.7738686276705613, 0.772887323943662, 0.7726836986365118, None)
#
# Confusion matrix:
#  [[211  73]
#  [ 56 228]]
#
# _______________________
#
#
# Article5
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 150 + 150 = 300 cases
# Cases available for testing(violation): 1118
# ***10-fold cross-validation***
# Accuracy: 0.6866666666666666
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.69      0.67      0.68       150
#     violation       0.68      0.70      0.69       150
#
#      accuracy                           0.69       300
#     macro avg       0.69      0.69      0.69       300
#  weighted avg       0.69      0.69      0.69       300
#
#
# CR: (0.686799501867995, 0.6866666666666666, 0.6866109530583214, None)
#
# Confusion matrix:
#  [[101  49]
#  [ 45 105]]
#
# _______________________
#
#
# Article6
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 458 + 458 = 916 cases
# Cases available for testing(violation): 4092
# ***10-fold cross-validation***
# Accuracy: 0.732532751091703
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.76      0.67      0.72       458
#     violation       0.71      0.79      0.75       458
#
#      accuracy                           0.73       916
#     macro avg       0.74      0.73      0.73       916
#  weighted avg       0.74      0.73      0.73       916
#
#
# CR: (0.7356889178806987, 0.732532751091703, 0.7316343137852812, None)
#
# Confusion matrix:
#  [[309 149]
#  [ 96 362]]
#
# _______________________
#
#
# Article8
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 106 + 106 = 212 cases
# Cases available for testing(violation): 252
# ***10-fold cross-validation***
# Accuracy: 0.6179245283018868
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.60      0.70      0.65       106
#     violation       0.64      0.54      0.58       106
#
#      accuracy                           0.62       212
#     macro avg       0.62      0.62      0.62       212
#  weighted avg       0.62      0.62      0.62       212
#
#
# CR: (0.6210377272312049, 0.6179245283018868, 0.6154517971111858, None)
#
# Confusion matrix:
#  [[74 32]
#  [49 57]]
#
# _______________________
#
#
# Article11
# Trained on *procedure* part of the cases
# [('PROCEDURE\n\n1.\xa0\xa0The case was referred to the Court by the European Commission of Human Rights (“the Commission”) on 28 October 1996, within the three-month period laid down by Article 32 § 1 and Article 47 of the Convention for the Protection of Human Rights and Fundamental Freedoms (“the Convention”). It originated in an application (no. 19392/92) against the Republic of Turkey lodged with the Commission under Article 25 by a political party, the United Communist Party of Turkey, and two Turkish nationals, Mr Nihat Sargın and Mr Nabi Yağcı, on 7 January 1992.\n\nThe Commission’s request referred to Articles 44 and 48 (a) of the Convention and to Rule 32 of Rules of Court A. The object of the request was to obtain a decision as to whether the facts of the case disclosed a breach by the respondent State of its obligations under Article 11 of the Convention.\n\n2.\xa0\xa0In response to the enquiry made in accordance with Rule 33 § 3 (d), the applicants stated that they wished to take part in the proceedings and designated the lawyers who would represent them (Rule\xa030). The lawyers were given leave by the President to use the Turkish language in the written and oral stages of the proceedings (Rule 27 § 3).\n\n3.\xa0\xa0The Chamber to be constituted included ex officio Mr F. Gölcüklü, the elected judge of Turkish nationality (Article 43 of the Convention), and Mr\xa0R.\xa0Ryssdal, the President of the Court (Rule 21 § 4 (b)). On 29 October 1996, in the presence of the Registrar, the President drew by lot the names of the other seven members, namely Mr B. Walsh, Mr C. Russo, Mr\xa0I.\xa0Foighel, Mr A.N. Loizou, Mr J. Makarczyk, Mr P. Kūris and Mr\xa0P.\xa0van Dijk (Article 43 in fine of the Convention and Rule 21 § 5).\n\n4.\xa0\xa0As President of the Chamber (Rule 21 § 6), Mr Ryssdal, acting through the Registrar, consulted the Agent of the Turkish Government (“the Government”), the applicants’ lawyers and the Delegate of the Commission on the organisation of the proceedings (Rules 37 § 1 and 38). Pursuant to the order made in consequence, the Registrar received the applicants’ memorial on 3 June 1997 and the Government’s memorial on 18 June.\n\n5.\xa0\xa0On 28 August 1997 the Chamber decided to relinquish jurisdiction forthwith in favour of a Grand Chamber (Rule 51). The Grand Chamber to be constituted included ex officio Mr Ryssdal, the President of the Court, and Mr R. Bernhardt, the Vice-President, together with the members and the four substitutes of the original Chamber, the latter being Mr A.B. Baka, Mr\xa0M.A. Lopes Rocha, Mr R. Pekkanen and Mr\xa0R.\xa0Macdonald (Rule 51 §\xa02\xa0(a) and (b)). On the same day the President, in the presence of the Registrar, drew by lot the names of the seven additional members needed to complete the Grand Chamber, namely Mr\xa0F.\xa0Matscher, Mr N. Valticos, Mrs\xa0E. Palm, Mr J.M. Morenilla, Sir\xa0John\xa0Freeland, Mr L. Wildhaber and Mr U. Lōhmus (Rule 51§\xa02 (c)). Subsequently Mr\xa0Ryssdal and Mr Walsh were unable to take part in the further consideration of the case (Rules 24 §\xa01 and 51 § 3). Mr Ryssdal’s place as President of the Grand Chamber was taken by Mr\xa0Bernhardt (Rules\xa021 § 6 and 51 § 6).\n\n6.\xa0\xa0In accordance with the President’s decision, the hearing took place in public in the Human Rights Building, Strasbourg, on 23 September 1997. The Court had held a preparatory meeting beforehand.\n\n\n\nThere appeared before the Court:\n\n\t•\tfor the Government\u2028Mr\tA. Gündüz, Professor of International Law,\u2028\t\t\tUniversity of Marmara,\tAgent,\u2028Mrs D. Akçay, Deputy Permanent Representative\u2028\t\t\tof Turkey to the Council of Europe,\u2028Mr\tM. Özmen, Ministry of Foreign Affairs,\u2028Mr\tŞ. Alpaslan, Doctor of Law,\u2028Mr\tA. Kaya, Ministry of Justice,\u2028Ms\tA. Emüler, Ministry of Foreign Affairs,\u2028Ms\tY. Renda, Ministry of Foreign Affairs,\u2028Mrs\tN. Ayman, Ministry of the Interior,\u2028Mr\tN. Alkan, Ministry of the Interio ...
# Training on 32 + 32 = 64 cases
# Cases available for testing(violation): 89
# ***10-fold cross-validation***
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 106 + 106 = 212 cases
# Cases available for testing(violation): 1060
# ***10-fold cross-validation***
# Accuracy: 0.7830188679245284
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.76      0.83      0.79       106
#     violation       0.81      0.74      0.77       106
#
#      accuracy                           0.78       212
#     macro avg       0.79      0.78      0.78       212
#  weighted avg       0.79      0.78      0.78       212
#
#
# CR: (0.7855603448275862, 0.7830188679245282, 0.7825350102577825, None)
#
# Confusion matrix:
#  [[88 18]
#  [28 78]]
#
# _______________________
#
#
# Article14
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Accuracy: 0.6944444444444444
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.68      0.74      0.71       144
#     violation       0.71      0.65      0.68       144
#
#      accuracy                           0.69       288
#     macro avg       0.70      0.69      0.69       288
#  weighted avg       0.70      0.69      0.69       288
#
#
# CR: (0.6958041958041958, 0.6944444444444444, 0.693913043478261, None)
#
# Confusion matrix:
#  [[106  38]
#  [ 50  94]]
#
# _______________________

# %%
from xgboost import XGBClassifier
def train_model_cross_val(Xtrain, Ytrain, vec, c): #Linear SVC model cross-validation
    print('***10-fold cross-validation***')
    pipeline = Pipeline([
        ('features', FeatureUnion(
            [vec],
        )),
        ('classifier', XGBClassifier())
        ])
    Ypredict = cross_val_predict(pipeline, Xtrain, Ytrain, cv=10) #10-fold cross-validation
    evaluate(Ytrain, Ypredict)

# %%
def train_model_test(Xtrain, Ytrain, Xtest_v, Ytest_v, vec, c): #test on 'violations' test set
    pipeline = Pipeline([
        ('features', FeatureUnion([vec]
        )),
        ('classifier', XGBClassifier())
        ])
    pipeline.fit(Xtrain, Ytrain)
    print('***testing on violation testset***')
    Ypredict = pipeline.predict(Xtest_v)
    evaluate(Ytest_v, Ypredict)

# %%
if __name__ == "__main__":
    ##INDICATE THE PATH TO THE DATA
    #path = '~/Documents/ECtHR_crystal_ball/'
    path = '/content/'
    articles = ['Article2', 'Article3', 'Article5', 'Article6', 'Article8', 'Article10', 'Article11', 'Article13', 'Article14']
    for article in articles: #the parameters were determined using grid-search
        print (article)
        if article == 'Article2':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', ngram_range = (3,4), binary = False, lowercase = True, min_df = 2, norm = 'l2', stop_words = None, use_idf = True))
            c = 0.1
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article3':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (1,1),  norm = None,  stop_words = None,  use_idf = True))
            c = 0.1
            run_pipeline('facts', vec, c)
        if article == 'Article5':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 1
            run_pipeline('facts', vec, c) 
        if article == 'Article6':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 2,  ngram_range = (2,4),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article8':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 1,  ngram_range = (3, 3),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 1
            run_pipeline('facts', vec, c)
        if article == 'Article10':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = False,  min_df = 1,  ngram_range = (1, 1),  norm = 'l2',  stop_words = None,  use_idf = False))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article11':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 2,  ngram_range = (1, 1),  norm = 'l1',  stop_words = 'english',  use_idf = False))
            c = 1
            run_pipeline('procedure', vec, c)
        if article == 'Article13':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = False,  lowercase = True,  min_df = 1,  ngram_range = (1, 2),  norm = 'l2',  stop_words = None,  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
        if article == 'Article14':
            vec = ('wordvec', TfidfVectorizer(analyzer = 'word', binary = True,  lowercase = True,  min_df = 3,  ngram_range = (1, 1),  norm = 'l2',  stop_words = 'english',  use_idf = True))
            c = 5
            run_pipeline('procedure+facts', vec, c)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 57 + 57 = 114 cases
# Cases available for testing(violation): 398
# ***10-fold cross-validation***
# Accuracy: 0.6754385964912281
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.67      0.68      0.68        57
#     violation       0.68      0.67      0.67        57
#
#      accuracy                           0.68       114
#     macro avg       0.68      0.68      0.68       114
#  weighted avg       0.68      0.68      0.68       114
#
#
# CR: (0.6754926108374384, 0.6754385964912281, 0.6754136206233166, None)
#
# Confusion matrix:
#  [[39 18]
#  [19 38]]
#
# _______________________
#
#
# Article3
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 284 + 284 = 568 cases
# Cases available for testing(violation): 851
# ***10-fold cross-validation***
# Accuracy: 0.7834507042253521
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.79      0.77      0.78       284
#     violation       0.78      0.80      0.79       284
#
#      accuracy                           0.78       568
#     macro avg       0.78      0.78      0.78       568
#  weighted avg       0.78      0.78      0.78       568
#
#
# CR: (0.7836230104085253, 0.7834507042253521, 0.7834178098116718, None)
#
# Confusion matrix:
#  [[219  65]
#  [ 58 226]]
#
# _______________________
#
#
# Article5
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 150 + 150 = 300 cases
# Cases available for testing(violation): 1118
# ***10-fold cross-validation***
# Accuracy: 0.7066666666666667
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.72      0.67      0.69       150
#     violation       0.69      0.75      0.72       150
#
#      accuracy                           0.71       300
#     macro avg       0.71      0.71      0.71       300
#  weighted avg       0.71      0.71      0.71       300
#
#
# CR: (0.7079978529253892, 0.7066666666666667, 0.7061965811965811, None)
#
# Confusion matrix:
#  [[100  50]
#  [ 38 112]]
#
# _______________________
#
#
# Article6
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 458 + 458 = 916 cases
# Cases available for testing(violation): 4092
# ***10-fold cross-validation***
# Accuracy: 0.7543668122270742
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.77      0.72      0.75       458
#     violation       0.74      0.79      0.76       458
#
#      accuracy                           0.75       916
#     macro avg       0.76      0.75      0.75       916
#  weighted avg       0.76      0.75      0.75       916
#
#
# CR: (0.7555375162234259, 0.7543668122270742, 0.754085157410556, None)
#
# Confusion matrix:
#  [[330 128]
#  [ 97 361]]
#
# _______________________
#
#
# Article8
# Trained on *facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 106 + 106 = 212 cases
# Cases available for testing(violation): 252
# ***10-fold cross-validation***
# Accuracy: 0.6226415094339622
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.62      0.62      0.62       106
#     violation       0.62      0.62      0.62       106
#
#      accuracy                           0.62       212
#     macro avg       0.62      0.62      0.62       212
#  weighted avg       0.62      0.62      0.62       212
#
#
# CR: (0.6226415094339622, 0.6226415094339622, 0.6226415094339622, None)
#
# Confusion matrix:
#  [[66 40]
#  [40 66]]
#
# _______________________
#
#
# Article11
# Trained on *procedure* part of the cases
# [('PROCEDURE\n\n1.\xa0\xa0The case was referred to the Court by the European Commission of Human Rights (“the Commission”) on 28 October 1996, within the three-month period laid down by Article 32 § 1 and Article 47 of the Convention for the Protection of Human Rights and Fundamental Freedoms (“the Convention”). It originated in an application (no. 19392/92) against the Republic of Turkey lodged with the Commission under Article 25 by a political party, the United Communist Party of Turkey, and two Turkish nationals, Mr Nihat Sargın and Mr Nabi Yağcı, on 7 January 1992.\n\nThe Commission’s request referred to Articles 44 and 48 (a) of the Convention and to Rule 32 of Rules of Court A. The object of the request was to obtain a decision as to whether the facts of the case disclosed a breach by the respondent State of its obligations under Article 11 of the Convention.\n\n2.\xa0\xa0In response to the enquiry made in accordance with Rule 33 § 3 (d), the applicants stated that they wished to take part in the proceedings and designated the lawyers who would represent them (Rule\xa030). The lawyers were given leave by the President to use the Turkish language in the written and oral stages of the proceedings (Rule 27 § 3).\n\n3.\xa0\xa0The Chamber to be constituted included ex officio Mr F. Gölcüklü, the elected judge of Turkish nationality (Article 43 of the Convention), and Mr\xa0R.\xa0Ryssdal, the President of the Court (Rule 21 § 4 (b)). On 29 October 1996, in the presence of the Registrar, the President drew by lot the names of the other seven members, namely Mr B. Walsh, Mr C. Russo, Mr\xa0I.\xa0Foighel, Mr A.N. Loizou, Mr J. Makarczyk, Mr P. Kūris and Mr\xa0P.\xa0van Dijk (Article 43 in fine of the Convention and Rule 21 § 5).\n\n4.\xa0\xa0As President of the Chamber (Rule 21 § 6), Mr Ryssdal, acting through the Registrar, consulted the Agent of the Turkish Government (“the Government”), the applicants’ lawyers and the Delegate of the Commission on the organisation of the proceedings (Rules 37 § 1 and 38). Pursuant to the order made in consequence, the Registrar received the applicants’ memorial on 3 June 1997 and the Government’s memorial on 18 June.\n\n5.\xa0\xa0On 28 August 1997 the Chamber decided to relinquish jurisdiction forthwith in favour of a Grand Chamber (Rule 51). The Grand Chamber to be constituted included ex officio Mr Ryssdal, the President of the Court, and Mr R. Bernhardt, the Vice-President, together with the members and the four substitutes of the original Chamber, the latter being Mr A.B. Baka, Mr\xa0M.A. Lopes Rocha, Mr R. Pekkanen and Mr\xa0R.\xa0Macdonald (Rule 51 §\xa02\xa0(a) and (b)). On the same day the President, in the presence of the Registrar, drew by lot the names of the seven additional members needed to complete the Grand Chamber, namely Mr\xa0F.\xa0Matscher, Mr N. Valticos, Mrs\xa0E. Palm, Mr J.M. Morenilla, Sir\xa0John\xa0Freeland, Mr L. Wildhaber and Mr U. Lōhmus (Rule 51§\xa02 (c)). Subsequently Mr\xa0Ryssdal and Mr Walsh were unable to take part in the further consideration of the case (Rules 24 §\xa01 and 51 § 3). Mr Ryssdal’s place as President of the Grand Chamber was taken by Mr\xa0Bernhardt (Rules\xa021 § 6 and 51 § 6).\n\n6.\xa0\xa0In accordance with the President’s decision, the hearing took place in public in the Human Rights Building, Strasbourg, on 23 September 1997. The Court had held a preparatory meeting beforehand.\n\n\n\nThere appeared before the Court:\n\n\t•\tfor the Government\u2028Mr\tA. Gündüz, Professor of International Law,\u2028\t\t\tUniversity of Marmara,\tAgent,\u2028Mrs D. Akçay, Deputy Permanent Representative\u2028\t\t\tof Turkey to the Council of Europe,\u2028Mr\tM. Özmen, Ministry of Foreign Affairs,\u2028Mr\tŞ. Alpaslan, Doctor of Law,\u2028Mr\tA. Kaya, Ministry of Justice,\u2028Ms\tA. Emüler, Ministry of Foreign Affairs,\u2028Ms\tY. Renda, Ministry of Foreign Affairs,\u2028Mrs\tN. Ayman, Ministry of the Interior,\u2028Mr\tN. Alkan, Ministry of the Interio ...
# Training on 32 + 32 = 64 cases
# Cases available for testing(violation): 89
# ***10-fold cross-validation***
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training on 106 + 106 = 212 cases
# Cases available for testing(violation): 1060
# ***10-fold cross-validation***
# Accuracy: 0.75
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.73      0.78      0.76       106
#     violation       0.77      0.72      0.74       106
#
#      accuracy                           0.75       212
#     macro avg       0.75      0.75      0.75       212
#  weighted avg       0.75      0.75      0.75       212
#
#
# CR: (0.7510950210065255, 0.75, 0.7497271411070275, None)
#
# Confusion matrix:
#  [[83 23]
#  [30 76]]
#
# _______________________
#
#
# Article14
# Trained on *procedure+facts* part of the cases
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Accuracy: 0.7048611111111112
#
# Classification report:
#                 precision    recall  f1-score   support
#
# non-violation       0.71      0.70      0.70       144
#     violation       0.70      0.71      0.71       144
#
#      accuracy                           0.70       288
#     macro avg       0.70      0.70      0.70       288
#  weighted avg       0.70      0.70      0.70       288
#
#
# CR: (0.7048709910778876, 0.7048611111111112, 0.7048575527772085, None)
#
# Confusion matrix:
#  [[101  43]
#  [ 42 102]]
#
# _______________________
